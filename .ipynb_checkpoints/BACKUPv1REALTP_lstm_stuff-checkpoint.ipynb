# %%
# [10:12 PM]

usingSavedModel = False

from datetime import *

# IMPORTANT note to self: this is the best working version so far.
# the other somewhat working but screwed up version is called 
# v1REALTP_lstm_stuff

# Author: Roshan Ram
# AndrewID: rram

import yfinance as yfinance

# import module_manager
# module_manager.review()

import yfinance as yf # to pull stock data with yf.download(name, yyyy-mm-dd of opening, yyyy-mm-dd of opening)

import numpy as np # used for everything lol
import pandas as pd # data mainpulation
import matplotlib.pyplot as plt # graphing/plotting
from keras import *

import time, random, copy

#####
import numpy as np
import os
import sys
import time
import pandas as pd 
# from tqdm._tqdm_notebook import tqdm_notebook
import pickle
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout
from keras.layers import LSTM
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger
from keras import optimizers
# from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import logging
####

# %matplotlib inline 
#just to make stuff look nice

# %%
TIME_STEPS = 10
batchSize = 32
min_max_scaler = MinMaxScaler()

# %%
stock = None
while not isinstance(stock, str):
    stock = input("Enter your desired stock. Only alphanumeric characters please.")
openingInp = input("Enter your desired opening date. (yyyy-mm-dd)") #'2016-01-01'
closingInp = input("Enter your desired closing date. (yyyy-mm-dd)") # '2019-08-01'


data = yf.download(stock, openingInp, closingInp)


def getData_LSTM(app):
    stock = None
#     while not isinstance(stock, str):
    stock = app.getUserInput("Enter your desired stock. Only alphanumeric characters please.")
    openingInp = app.getUserInput("Enter your desired opening date. (yyyy-mm-dd)") #'2016-01-01'
    closingInp = app.getUserInput("Enter your desired closing date. (yyyy-mm-dd)") # '2019-08-01'


    data = yf.download(stock, openingInp, closingInp)
    return data, stock 

# data, stock = getData(app)
# Out:
# Enter your desired stock. Only alphanumeric characters please.AAPL
# Enter your desired opening date. (yyyy-mm-dd)2016-08-01
# Enter your desired closing date. (yyyy-mm-dd)2019-01-01
# [*********************100%***********************]  1 of 1 completed

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

def mainFunc1(data):

#     TIME_STEPS = 10 # [rram]
#     batchSize = 32 # [rram]


#     #####
#     params = {
#         "batch_size": 20,  # 20<16<10, 25 was a bust
#         "epochs": 300,
#         "lr": 0.00010000,
#         "time_steps": 60
#     }

#     iter_changes = "dropout_layers_0.4_0.4"

#     # INPUT_PATH = PATH_TO_DRIVE_ML_DATA+"/inputs"
#     OUTPUT_PATH = '~/Desktop'
#     TIME_STEPS = params["time_steps"]
#     batchSize = params["batch_size"]
#     stime = time.time()
#     ###


    train_cols = ["Open","High","Low","Close","Volume"]
    df_train, df_test = train_test_split(data, train_size=0.8, test_size=0.2, shuffle=False)
    print("Train and Test size", len(df_train), len(df_test))
    # scale the feature MinMax, build array
    x = df_train.loc[:,train_cols].values
    x_train = min_max_scaler.fit_transform(x)
    x_test = min_max_scaler.transform(df_test.loc[:,train_cols])

    return x_train, x_test

# %%
x_train, x_test = mainFunc1(data)  # IMP!
# Out:
# Train and Test size 487 122

# %%
def createTimesteps(mat, y_col_index):
    # y_col_index is the index of column that would act as output column
    # total number of time-series samples would be len(mat) - TIME_STEPS
    dim_0 = mat.shape[0] - TIME_STEPS
    dim_1 = mat.shape[1]
    x = np.zeros((dim_0, TIME_STEPS, dim_1))
    y = np.zeros((dim_0,))

    for i in (range(dim_0)):
        x[i] = mat[i:TIME_STEPS+i]
        y[i] = mat[TIME_STEPS+i, y_col_index]
    print("length of time-series i/o",x.shape,y.shape)
    return x, y

def createDataset(mat, batch_size):
    """
    trims dataset to a size that's divisible by batchSize
    """
    no_of_rows_drop = mat.shape[0]%batch_size
    if(no_of_rows_drop > 0):
        return mat[:-no_of_rows_drop]
    else:
        return mat

# %%
def mainFunc2(x_test, x_train):
    x_t, y_t = createTimesteps(x_train, 3)
    x_t = createDataset(x_t, batchSize)
    y_t = createDataset(y_t, batchSize)
    x_temp, y_temp = createTimesteps(x_test, 3)
    x_val, x_test_t = np.split(createDataset(x_temp, batchSize),2)
    y_val, y_test_t = np.split(createDataset(y_temp, batchSize),2)
    return x_t, y_t, x_val, x_test_t, y_val, y_test_t

# %%
x_t, y_t, x_val, x_test_t, y_val, y_test_t = mainFunc2(x_test, x_train)  # IMP!
# Out:
# length of time-series i/o (477, 10, 5) (477,)
# length of time-series i/o (112, 10, 5) (112,)

# %%
# this function creates a model with MSE as an accuracy-measuring metric

def create_model(x_t):
    lstm_model = Sequential()
    lstm_model.add(LSTM(100, batch_input_shape=(batchSize, TIME_STEPS, x_t.shape[2]), dropout=0.0, recurrent_dropout=0.0, stateful=True,     kernel_initializer='random_uniform'))
    lstm_model.add(Dropout(0.5))
    lstm_model.add(Dense(20,activation='relu'))
    lstm_model.add(Dense(1,activation='sigmoid'))
    optimizer = optimizers.RMSprop(lr=0.00010000)
    lstm_model.compile(loss='mean_squared_error', optimizer=optimizer)
    model = lstm_model
    return model

# %%
if not usingSavedModel:
    model = create_model(x_t)  # IMP!
    
    today = date.today()
    d4 = today.strftime("%b-%d-%Y")
    # ^Credit: https://www.programiz.com/python-programming/datetime/current-datetime

    fileName = f'{d4}_savedLSTM.h5' 
    model.save(fileName)
    print(f"Saved model `{fileName}` to disk")
else:
    today = date.today()
    d4 = today.strftime("%b-%d-%Y")
    # ^Credit: https://www.programiz.com/python-programming/datetime/current-datetime

    fileName = f'{d4}_savedLSTM.h5' 
    model = load_model(fileName)

# %%
def trainModel(x_t, y_t, x_val, y_val, model, numEpochs):
    # csv_logger = CSVLogger(os.path.join(OUTPUT_PATH, 'your_log_name' + '.log'), append=True) #dont need this line

    # epochs = params['epochs']


    # NOTE TO SELF CHANGE EPOCHS BACK to 300
    history = model.fit(x_t, y_t, epochs= numEpochs, verbose=2, batch_size=batchSize,
                        shuffle=False, validation_data=(createDataset(x_val, batchSize),
                        createDataset(y_val, batchSize))) #callbacks=[csv_logger])

    return history

# %%
if not usingSavedModel:
    history = trainModel(x_t, y_t, x_val, y_val, model, 300)  # IMP!
# Out:
# Train on 448 samples, validate on 32 samples
# Epoch 1/300
#  - 1s - loss: 0.0675 - val_loss: 0.4290
# Epoch 2/300
#  - 0s - loss: 0.0654 - val_loss: 0.4055
# Epoch 3/300
#  - 0s - loss: 0.0639 - val_loss: 0.3848
# Epoch 4/300
#  - 0s - loss: 0.0626 - val_loss: 0.3619
# Epoch 5/300
#  - 0s - loss: 0.0612 - val_loss: 0.3407
# Epoch 6/300
#  - 0s - loss: 0.0596 - val_loss: 0.3192
# Epoch 7/300
#  - 0s - loss: 0.0592 - val_loss: 0.2985
# Epoch 8/300
#  - 0s - loss: 0.0581 - val_loss: 0.2792
# Epoch 9/300
#  - 0s - loss: 0.0568 - val_loss: 0.2623
# Epoch 10/300
#  - 0s - loss: 0.0568 - val_loss: 0.2469
# Epoch 11/300
#  - 0s - loss: 0.0551 - val_loss: 0.2322
# Epoch 12/300
#  - 0s - loss: 0.0546 - val_loss: 0.2190
# Epoch 13/300
#  - 0s - loss: 0.0537 - val_loss: 0.2060
# Epoch 14/300
#  - 0s - loss: 0.0528 - val_loss: 0.1945
# Epoch 15/300
#  - 0s - loss: 0.0519 - val_loss: 0.1849
# Epoch 16/300
#  - 0s - loss: 0.0502 - val_loss: 0.1744
# Epoch 17/300
#  - 0s - loss: 0.0494 - val_loss: 0.1650
# Epoch 18/300
#  - 0s - loss: 0.0482 - val_loss: 0.1561
# Epoch 19/300
#  - 0s - loss: 0.0472 - val_loss: 0.1503
# Epoch 20/300
#  - 0s - loss: 0.0458 - val_loss: 0.1437
# Epoch 21/300
#  - 0s - loss: 0.0446 - val_loss: 0.1360
# Epoch 22/300
#  - 0s - loss: 0.0426 - val_loss: 0.1282
# Epoch 23/300
#  - 0s - loss: 0.0414 - val_loss: 0.1222
# Epoch 24/300
#  - 0s - loss: 0.0395 - val_loss: 0.1155
# Epoch 25/300
#  - 0s - loss: 0.0374 - val_loss: 0.1098
# Epoch 26/300
#  - 0s - loss: 0.0364 - val_loss: 0.1040
# Epoch 27/300
#  - 0s - loss: 0.0337 - val_loss: 0.0999
# Epoch 28/300
#  - 0s - loss: 0.0321 - val_loss: 0.0942
# Epoch 29/300
#  - 0s - loss: 0.0304 - val_loss: 0.0916
# Epoch 30/300
#  - 0s - loss: 0.0276 - val_loss: 0.0867
# Epoch 31/300
#  - 0s - loss: 0.0269 - val_loss: 0.0815
# Epoch 32/300
#  - 0s - loss: 0.0240 - val_loss: 0.0802
# Epoch 33/300
#  - 0s - loss: 0.0217 - val_loss: 0.0768
# Epoch 34/300
#  - 0s - loss: 0.0204 - val_loss: 0.0745
# Epoch 35/300
#  - 0s - loss: 0.0183 - val_loss: 0.0715
# Epoch 36/300
#  - 0s - loss: 0.0160 - val_loss: 0.0703
# Epoch 37/300
#  - 0s - loss: 0.0143 - val_loss: 0.0687
# Epoch 38/300
#  - 0s - loss: 0.0148 - val_loss: 0.0690
# Epoch 39/300
#  - 0s - loss: 0.0130 - val_loss: 0.0676
# Epoch 40/300
#  - 0s - loss: 0.0119 - val_loss: 0.0676
# Epoch 41/300
#  - 0s - loss: 0.0111 - val_loss: 0.0676
# Epoch 42/300
#  - 0s - loss: 0.0104 - val_loss: 0.0667
# Epoch 43/300
#  - 0s - loss: 0.0100 - val_loss: 0.0666
# Epoch 44/300
#  - 0s - loss: 0.0093 - val_loss: 0.0646
# Epoch 45/300
#  - 0s - loss: 0.0099 - val_loss: 0.0652
# Epoch 46/300
#  - 0s - loss: 0.0089 - val_loss: 0.0644
# Epoch 47/300
#  - 0s - loss: 0.0084 - val_loss: 0.0659
# Epoch 48/300
#  - 0s - loss: 0.0082 - val_loss: 0.0643
# Epoch 49/300
#  - 0s - loss: 0.0081 - val_loss: 0.0646
# Epoch 50/300
#  - 0s - loss: 0.0080 - val_loss: 0.0627
# Epoch 51/300
#  - 0s - loss: 0.0084 - val_loss: 0.0623
# Epoch 52/300
#  - 0s - loss: 0.0078 - val_loss: 0.0625
# Epoch 53/300
#  - 0s - loss: 0.0081 - val_loss: 0.0631
# Epoch 54/300
#  - 0s - loss: 0.0072 - val_loss: 0.0638
# Epoch 55/300
#  - 0s - loss: 0.0072 - val_loss: 0.0626
# Epoch 56/300
#  - 0s - loss: 0.0070 - val_loss: 0.0629
# Epoch 57/300
#  - 0s - loss: 0.0071 - val_loss: 0.0626
# Epoch 58/300
#  - 0s - loss: 0.0070 - val_loss: 0.0630
# Epoch 59/300
#  - 0s - loss: 0.0065 - val_loss: 0.0641
# Epoch 60/300
#  - 0s - loss: 0.0059 - val_loss: 0.0626
# Epoch 61/300
#  - 0s - loss: 0.0064 - val_loss: 0.0619
# Epoch 62/300
#  - 0s - loss: 0.0057 - val_loss: 0.0622
# Epoch 63/300
#  - 0s - loss: 0.0058 - val_loss: 0.0630
# Epoch 64/300
#  - 0s - loss: 0.0052 - val_loss: 0.0622
# Epoch 65/300
#  - 0s - loss: 0.0059 - val_loss: 0.0625
# Epoch 66/300
#  - 0s - loss: 0.0052 - val_loss: 0.0614
# Epoch 67/300
#  - 0s - loss: 0.0062 - val_loss: 0.0618
# Epoch 68/300
#  - 0s - loss: 0.0054 - val_loss: 0.0629
# Epoch 69/300
#  - 0s - loss: 0.0058 - val_loss: 0.0632
# Epoch 70/300
#  - 0s - loss: 0.0056 - val_loss: 0.0623
# Epoch 71/300
#  - 0s - loss: 0.0049 - val_loss: 0.0629
# Epoch 72/300
#  - 0s - loss: 0.0053 - val_loss: 0.0625
# Epoch 73/300
#  - 0s - loss: 0.0050 - val_loss: 0.0617
# Epoch 74/300
#  - 0s - loss: 0.0054 - val_loss: 0.0625
# Epoch 75/300
#  - 0s - loss: 0.0049 - val_loss: 0.0617
# Epoch 76/300
#  - 0s - loss: 0.0046 - val_loss: 0.0622
# Epoch 77/300
#  - 0s - loss: 0.0041 - val_loss: 0.0617
# Epoch 78/300
#  - 0s - loss: 0.0045 - val_loss: 0.0623
# Epoch 79/300
#  - 0s - loss: 0.0042 - val_loss: 0.0626
# Epoch 80/300
#  - 0s - loss: 0.0050 - val_loss: 0.0619
# Epoch 81/300
#  - 0s - loss: 0.0048 - val_loss: 0.0610
# Epoch 82/300
#  - 0s - loss: 0.0047 - val_loss: 0.0617
# Epoch 83/300
#  - 0s - loss: 0.0046 - val_loss: 0.0624
# Epoch 84/300
#  - 0s - loss: 0.0044 - val_loss: 0.0626
# Epoch 85/300
#  - 0s - loss: 0.0044 - val_loss: 0.0641
# Epoch 86/300
#  - 0s - loss: 0.0043 - val_loss: 0.0623
# Epoch 87/300
#  - 0s - loss: 0.0048 - val_loss: 0.0632
# Epoch 88/300
#  - 0s - loss: 0.0041 - val_loss: 0.0640
# Epoch 89/300
#  - 0s - loss: 0.0043 - val_loss: 0.0637
# Epoch 90/300
#  - 0s - loss: 0.0045 - val_loss: 0.0629
# Epoch 91/300
#  - 0s - loss: 0.0043 - val_loss: 0.0642
# Epoch 92/300
#  - 0s - loss: 0.0039 - val_loss: 0.0644
# Epoch 93/300
#  - 0s - loss: 0.0042 - val_loss: 0.0625
# Epoch 94/300
#  - 0s - loss: 0.0042 - val_loss: 0.0644
# Epoch 95/300
#  - 0s - loss: 0.0040 - val_loss: 0.0642
# Epoch 96/300
#  - 0s - loss: 0.0043 - val_loss: 0.0670
# Epoch 97/300
#  - 0s - loss: 0.0041 - val_loss: 0.0643
# Epoch 98/300
#  - 0s - loss: 0.0040 - val_loss: 0.0663
# Epoch 99/300
#  - 0s - loss: 0.0038 - val_loss: 0.0643
# Epoch 100/300
#  - 0s - loss: 0.0040 - val_loss: 0.0646
# Epoch 101/300
#  - 0s - loss: 0.0039 - val_loss: 0.0650
# Epoch 102/300
#  - 0s - loss: 0.0039 - val_loss: 0.0669
# Epoch 103/300
#  - 0s - loss: 0.0039 - val_loss: 0.0648
# Epoch 104/300
#  - 0s - loss: 0.0039 - val_loss: 0.0645
# Epoch 105/300
#  - 0s - loss: 0.0039 - val_loss: 0.0645
# Epoch 106/300
#  - 0s - loss: 0.0039 - val_loss: 0.0641
# Epoch 107/300
#  - 0s - loss: 0.0038 - val_loss: 0.0648
# Epoch 108/300
#  - 0s - loss: 0.0036 - val_loss: 0.0647
# Epoch 109/300
#  - 0s - loss: 0.0039 - val_loss: 0.0655
# Epoch 110/300
#  - 0s - loss: 0.0037 - val_loss: 0.0644
# Epoch 111/300
#  - 0s - loss: 0.0037 - val_loss: 0.0640
# Epoch 112/300
#  - 0s - loss: 0.0037 - val_loss: 0.0632
# Epoch 113/300
#  - 0s - loss: 0.0037 - val_loss: 0.0640
# Epoch 114/300
#  - 0s - loss: 0.0034 - val_loss: 0.0651
# Epoch 115/300
#  - 0s - loss: 0.0039 - val_loss: 0.0640
# Epoch 116/300
#  - 0s - loss: 0.0038 - val_loss: 0.0639
# Epoch 117/300
#  - 0s - loss: 0.0033 - val_loss: 0.0651
# Epoch 118/300
#  - 0s - loss: 0.0039 - val_loss: 0.0645
# Epoch 119/300
#  - 0s - loss: 0.0033 - val_loss: 0.0651
# Epoch 120/300
#  - 0s - loss: 0.0037 - val_loss: 0.0648
# Epoch 121/300
#  - 0s - loss: 0.0036 - val_loss: 0.0652
# Epoch 122/300
#  - 0s - loss: 0.0039 - val_loss: 0.0653
# Epoch 123/300
#  - 0s - loss: 0.0036 - val_loss: 0.0650
# Epoch 124/300
#  - 0s - loss: 0.0033 - val_loss: 0.0648
# Epoch 125/300
#  - 0s - loss: 0.0030 - val_loss: 0.0646
# Epoch 126/300
#  - 0s - loss: 0.0035 - val_loss: 0.0653
# Epoch 127/300
#  - 0s - loss: 0.0034 - val_loss: 0.0651
# Epoch 128/300
#  - 0s - loss: 0.0035 - val_loss: 0.0659
# Epoch 129/300
#  - 0s - loss: 0.0032 - val_loss: 0.0642
# Epoch 130/300
#  - 0s - loss: 0.0031 - val_loss: 0.0632
# Epoch 131/300
#  - 0s - loss: 0.0033 - val_loss: 0.0649
# Epoch 132/300
#  - 0s - loss: 0.0035 - val_loss: 0.0649
# Epoch 133/300
#  - 0s - loss: 0.0035 - val_loss: 0.0655
# Epoch 134/300
#  - 0s - loss: 0.0034 - val_loss: 0.0655
# Epoch 135/300
#  - 0s - loss: 0.0032 - val_loss: 0.0649
# Epoch 136/300
#  - 0s - loss: 0.0034 - val_loss: 0.0656
# Epoch 137/300
#  - 0s - loss: 0.0035 - val_loss: 0.0664
# Epoch 138/300
#  - 0s - loss: 0.0032 - val_loss: 0.0661
# Epoch 139/300
#  - 0s - loss: 0.0032 - val_loss: 0.0674
# Epoch 140/300
#  - 0s - loss: 0.0029 - val_loss: 0.0664
# Epoch 141/300
#  - 0s - loss: 0.0032 - val_loss: 0.0652
# Epoch 142/300
#  - 0s - loss: 0.0033 - val_loss: 0.0657
# Epoch 143/300
#  - 0s - loss: 0.0031 - val_loss: 0.0654
# Epoch 144/300
#  - 0s - loss: 0.0031 - val_loss: 0.0665
# Epoch 145/300
#  - 0s - loss: 0.0031 - val_loss: 0.0650
# Epoch 146/300
#  - 0s - loss: 0.0028 - val_loss: 0.0677
# Epoch 147/300
#  - 0s - loss: 0.0034 - val_loss: 0.0668
# Epoch 148/300
#  - 0s - loss: 0.0031 - val_loss: 0.0650
# Epoch 149/300
#  - 0s - loss: 0.0032 - val_loss: 0.0660
# Epoch 150/300
#  - 0s - loss: 0.0031 - val_loss: 0.0646
# Epoch 151/300
#  - 0s - loss: 0.0031 - val_loss: 0.0658
# Epoch 152/300
#  - 0s - loss: 0.0030 - val_loss: 0.0664
# Epoch 153/300
#  - 0s - loss: 0.0029 - val_loss: 0.0644
# Epoch 154/300
#  - 0s - loss: 0.0032 - val_loss: 0.0671
# Epoch 155/300
#  - 0s - loss: 0.0028 - val_loss: 0.0661
# Epoch 156/300
#  - 0s - loss: 0.0031 - val_loss: 0.0652
# Epoch 157/300
#  - 0s - loss: 0.0030 - val_loss: 0.0654
# Epoch 158/300
#  - 0s - loss: 0.0029 - val_loss: 0.0657
# Epoch 159/300
#  - 0s - loss: 0.0032 - val_loss: 0.0652
# Epoch 160/300
#  - 0s - loss: 0.0028 - val_loss: 0.0649
# Epoch 161/300
#  - 0s - loss: 0.0031 - val_loss: 0.0653
# Epoch 162/300
#  - 0s - loss: 0.0030 - val_loss: 0.0647
# Epoch 163/300
#  - 0s - loss: 0.0029 - val_loss: 0.0649
# Epoch 164/300
#  - 0s - loss: 0.0028 - val_loss: 0.0648
# Epoch 165/300
#  - 0s - loss: 0.0030 - val_loss: 0.0647
# Epoch 166/300
#  - 0s - loss: 0.0030 - val_loss: 0.0641
# Epoch 167/300
#  - 0s - loss: 0.0031 - val_loss: 0.0647
# Epoch 168/300
#  - 0s - loss: 0.0026 - val_loss: 0.0640
# Epoch 169/300
#  - 0s - loss: 0.0029 - val_loss: 0.0654
# Epoch 170/300
#  - 0s - loss: 0.0029 - val_loss: 0.0650
# Epoch 171/300
#  - 0s - loss: 0.0028 - val_loss: 0.0645
# Epoch 172/300
#  - 0s - loss: 0.0028 - val_loss: 0.0645
# Epoch 173/300
#  - 0s - loss: 0.0026 - val_loss: 0.0637
# Epoch 174/300
#  - 0s - loss: 0.0027 - val_loss: 0.0639
# Epoch 175/300
#  - 0s - loss: 0.0028 - val_loss: 0.0649
# Epoch 176/300
#  - 0s - loss: 0.0028 - val_loss: 0.0633
# Epoch 177/300
#  - 0s - loss: 0.0026 - val_loss: 0.0630
# Epoch 178/300
#  - 0s - loss: 0.0027 - val_loss: 0.0631
# Epoch 179/300
#  - 0s - loss: 0.0028 - val_loss: 0.0631
# Epoch 180/300
#  - 0s - loss: 0.0029 - val_loss: 0.0639
# Epoch 181/300
#  - 0s - loss: 0.0028 - val_loss: 0.0641
# Epoch 182/300
#  - 0s - loss: 0.0028 - val_loss: 0.0642
# Epoch 183/300
#  - 0s - loss: 0.0028 - val_loss: 0.0638
# Epoch 184/300
#  - 0s - loss: 0.0028 - val_loss: 0.0639
# Epoch 185/300
#  - 0s - loss: 0.0028 - val_loss: 0.0638
# Epoch 186/300
#  - 0s - loss: 0.0027 - val_loss: 0.0634
# Epoch 187/300
#  - 0s - loss: 0.0028 - val_loss: 0.0614
# Epoch 188/300
#  - 0s - loss: 0.0027 - val_loss: 0.0620
# Epoch 189/300
#  - 0s - loss: 0.0025 - val_loss: 0.0648
# Epoch 190/300
#  - 0s - loss: 0.0025 - val_loss: 0.0628
# Epoch 191/300
#  - 0s - loss: 0.0028 - val_loss: 0.0632
# Epoch 192/300
#  - 0s - loss: 0.0027 - val_loss: 0.0636
# Epoch 193/300
#  - 0s - loss: 0.0027 - val_loss: 0.0640
# Epoch 194/300
#  - 0s - loss: 0.0025 - val_loss: 0.0622
# Epoch 195/300
#  - 0s - loss: 0.0027 - val_loss: 0.0639
# Epoch 196/300
#  - 0s - loss: 0.0025 - val_loss: 0.0636
# Epoch 197/300
#  - 0s - loss: 0.0023 - val_loss: 0.0631
# Epoch 198/300
#  - 0s - loss: 0.0025 - val_loss: 0.0625
# Epoch 199/300
#  - 0s - loss: 0.0025 - val_loss: 0.0618
# Epoch 200/300
#  - 0s - loss: 0.0024 - val_loss: 0.0628
# Epoch 201/300
#  - 0s - loss: 0.0026 - val_loss: 0.0636
# Epoch 202/300
#  - 0s - loss: 0.0027 - val_loss: 0.0628
# Epoch 203/300
#  - 0s - loss: 0.0028 - val_loss: 0.0627
# Epoch 204/300
#  - 0s - loss: 0.0026 - val_loss: 0.0631
# Epoch 205/300
#  - 0s - loss: 0.0024 - val_loss: 0.0632
# Epoch 206/300
#  - 0s - loss: 0.0025 - val_loss: 0.0641
# Epoch 207/300
#  - 0s - loss: 0.0023 - val_loss: 0.0623
# Epoch 208/300
#  - 0s - loss: 0.0025 - val_loss: 0.0618
# Epoch 209/300
#  - 0s - loss: 0.0026 - val_loss: 0.0619
# Epoch 210/300
#  - 0s - loss: 0.0025 - val_loss: 0.0632
# Epoch 211/300
#  - 0s - loss: 0.0024 - val_loss: 0.0630
# Epoch 212/300
#  - 0s - loss: 0.0025 - val_loss: 0.0622
# Epoch 213/300
#  - 0s - loss: 0.0025 - val_loss: 0.0631
# Epoch 214/300
#  - 0s - loss: 0.0023 - val_loss: 0.0622
# Epoch 215/300
#  - 0s - loss: 0.0025 - val_loss: 0.0622
# Epoch 216/300
#  - 0s - loss: 0.0025 - val_loss: 0.0630
# Epoch 217/300
#  - 0s - loss: 0.0024 - val_loss: 0.0640
# Epoch 218/300
#  - 0s - loss: 0.0023 - val_loss: 0.0643
# Epoch 219/300
#  - 0s - loss: 0.0024 - val_loss: 0.0623
# Epoch 220/300
#  - 0s - loss: 0.0026 - val_loss: 0.0642
# Epoch 221/300
#  - 0s - loss: 0.0022 - val_loss: 0.0649
# Epoch 222/300
#  - 0s - loss: 0.0023 - val_loss: 0.0629
# Epoch 223/300
#  - 0s - loss: 0.0024 - val_loss: 0.0630
# Epoch 224/300
#  - 0s - loss: 0.0021 - val_loss: 0.0614
# Epoch 225/300
#  - 0s - loss: 0.0026 - val_loss: 0.0622
# Epoch 226/300
#  - 0s - loss: 0.0022 - val_loss: 0.0621
# Epoch 227/300
#  - 0s - loss: 0.0023 - val_loss: 0.0616
# Epoch 228/300
#  - 0s - loss: 0.0022 - val_loss: 0.0626
# Epoch 229/300
#  - 0s - loss: 0.0024 - val_loss: 0.0615
# Epoch 230/300
#  - 0s - loss: 0.0024 - val_loss: 0.0616
# Epoch 231/300
#  - 0s - loss: 0.0023 - val_loss: 0.0625
# Epoch 232/300
#  - 0s - loss: 0.0020 - val_loss: 0.0621
# Epoch 233/300
#  - 0s - loss: 0.0024 - val_loss: 0.0647
# Epoch 234/300
#  - 0s - loss: 0.0022 - val_loss: 0.0632
# Epoch 235/300
#  - 0s - loss: 0.0023 - val_loss: 0.0629
# Epoch 236/300
#  - 0s - loss: 0.0023 - val_loss: 0.0620
# Epoch 237/300
#  - 0s - loss: 0.0024 - val_loss: 0.0616
# Epoch 238/300
#  - 0s - loss: 0.0022 - val_loss: 0.0631
# Epoch 239/300
#  - 0s - loss: 0.0022 - val_loss: 0.0628
# Epoch 240/300
#  - 0s - loss: 0.0022 - val_loss: 0.0640
# Epoch 241/300
#  - 0s - loss: 0.0022 - val_loss: 0.0622
# Epoch 242/300
#  - 0s - loss: 0.0024 - val_loss: 0.0628
# Epoch 243/300
#  - 0s - loss: 0.0022 - val_loss: 0.0615
# Epoch 244/300
#  - 0s - loss: 0.0023 - val_loss: 0.0637
# Epoch 245/300
#  - 0s - loss: 0.0022 - val_loss: 0.0638
# Epoch 246/300
#  - 0s - loss: 0.0019 - val_loss: 0.0629
# Epoch 247/300
#  - 0s - loss: 0.0023 - val_loss: 0.0634
# Epoch 248/300
#  - 0s - loss: 0.0021 - val_loss: 0.0631
# Epoch 249/300
#  - 0s - loss: 0.0024 - val_loss: 0.0642
# Epoch 250/300
#  - 0s - loss: 0.0025 - val_loss: 0.0626
# Epoch 251/300
#  - 0s - loss: 0.0023 - val_loss: 0.0625
# Epoch 252/300
#  - 0s - loss: 0.0020 - val_loss: 0.0614
# Epoch 253/300
#  - 0s - loss: 0.0023 - val_loss: 0.0632
# Epoch 254/300
#  - 0s - loss: 0.0021 - val_loss: 0.0639
# Epoch 255/300
#  - 0s - loss: 0.0021 - val_loss: 0.0639
# Epoch 256/300
#  - 0s - loss: 0.0021 - val_loss: 0.0641
# Epoch 257/300
#  - 0s - loss: 0.0022 - val_loss: 0.0651
# Epoch 258/300
#  - 0s - loss: 0.0022 - val_loss: 0.0622
# Epoch 259/300
#  - 0s - loss: 0.0021 - val_loss: 0.0626
# Epoch 260/300
#  - 0s - loss: 0.0021 - val_loss: 0.0622
# Epoch 261/300
#  - 0s - loss: 0.0021 - val_loss: 0.0619
# Epoch 262/300
#  - 0s - loss: 0.0021 - val_loss: 0.0632
# Epoch 263/300
#  - 0s - loss: 0.0022 - val_loss: 0.0629
# Epoch 264/300
#  - 0s - loss: 0.0022 - val_loss: 0.0610
# Epoch 265/300
#  - 0s - loss: 0.0019 - val_loss: 0.0635
# Epoch 266/300
#  - 0s - loss: 0.0020 - val_loss: 0.0626
# Epoch 267/300
#  - 0s - loss: 0.0020 - val_loss: 0.0633
# Epoch 268/300
#  - 0s - loss: 0.0018 - val_loss: 0.0634
# Epoch 269/300
#  - 0s - loss: 0.0020 - val_loss: 0.0660
# Epoch 270/300
#  - 0s - loss: 0.0020 - val_loss: 0.0640
# Epoch 271/300
#  - 0s - loss: 0.0021 - val_loss: 0.0632
# Epoch 272/300
#  - 0s - loss: 0.0019 - val_loss: 0.0635
# Epoch 273/300
#  - 0s - loss: 0.0019 - val_loss: 0.0641
# Epoch 274/300
#  - 0s - loss: 0.0020 - val_loss: 0.0652
# Epoch 275/300
#  - 0s - loss: 0.0020 - val_loss: 0.0644
# Epoch 276/300
#  - 0s - loss: 0.0019 - val_loss: 0.0626
# Epoch 277/300
#  - 0s - loss: 0.0020 - val_loss: 0.0646
# Epoch 278/300
#  - 0s - loss: 0.0018 - val_loss: 0.0637
# Epoch 279/300
#  - 0s - loss: 0.0020 - val_loss: 0.0630
# Epoch 280/300
#  - 0s - loss: 0.0018 - val_loss: 0.0648
# Epoch 281/300
#  - 0s - loss: 0.0018 - val_loss: 0.0649
# Epoch 282/300
#  - 0s - loss: 0.0018 - val_loss: 0.0633
# Epoch 283/300
#  - 0s - loss: 0.0019 - val_loss: 0.0630
# Epoch 284/300
#  - 0s - loss: 0.0018 - val_loss: 0.0642
# Epoch 285/300
#  - 0s - loss: 0.0019 - val_loss: 0.0642
# Epoch 286/300
#  - 0s - loss: 0.0019 - val_loss: 0.0658
# Epoch 287/300
#  - 0s - loss: 0.0018 - val_loss: 0.0651
# Epoch 288/300
#  - 0s - loss: 0.0018 - val_loss: 0.0649
# Epoch 289/300
#  - 0s - loss: 0.0021 - val_loss: 0.0641
# Epoch 290/300
#  - 0s - loss: 0.0019 - val_loss: 0.0637
# Epoch 291/300
#  - 0s - loss: 0.0016 - val_loss: 0.0643
# Epoch 292/300
#  - 0s - loss: 0.0020 - val_loss: 0.0640
# Epoch 293/300
#  - 0s - loss: 0.0019 - val_loss: 0.0646
# Epoch 294/300
#  - 0s - loss: 0.0020 - val_loss: 0.0637
# Epoch 295/300
#  - 0s - loss: 0.0017 - val_loss: 0.0641
# Epoch 296/300
#  - 0s - loss: 0.0016 - val_loss: 0.0615
# Epoch 297/300
#  - 0s - loss: 0.0018 - val_loss: 0.0638
# Epoch 298/300
#  - 0s - loss: 0.0018 - val_loss: 0.0628
# Epoch 299/300
#  - 0s - loss: 0.0019 - val_loss: 0.0642
# Epoch 300/300
#  - 0s - loss: 0.0019 - val_loss: 0.0654

# %%
# update: SAVED MODEL!!! IMPORTANT WILL SAVE TIME ON FRONTEND FOR USER [12/4/19]

# now = datetime.now()
# dt_string = now.strftime("%d/%m/%Y %H:%M:%S")


# pickling model to save time on frontend
if not usingSavedModel:
    today = date.today()
    d4 = today.strftime("%b-%d-%Y")
    # print("date and time =", dt_string)	

    # ^Credit: https://www.programiz.com/python-programming/datetime/current-datetime

    fileName = f'{d4}_savedLSTM.h5' # <<--- doesn't work for some reason, commenting out for now [9:49 PM]
    model.save(fileName)
    print(f"Saved model `{fileName}` to disk")
#######################################################################################################

def createPredictions_LSTM(model, x_test_t, y_test_t):
    y_pred = model.predict(createDataset(x_test_t, batchSize), batch_size=batchSize)
    y_pred = y_pred.flatten()
    y_test_t = createDataset(y_test_t, batchSize)
    error = mean_squared_error(y_test_t, y_pred)
    print("Error is", error, y_pred.shape, y_test_t.shape)
    print(y_pred[0:15])
    print(y_test_t[0:15])

    # convert the predicted value to range of real data
    y_pred_org = (y_pred * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3]
    # min_max_scaler.inverse_transform(y_pred)
    y_test_t_org = (y_test_t * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3]
    # min_max_scaler.inverse_transform(y_test_t)
    print(y_pred_org[0:15])
    print(y_test_t_org[0:15])
    
    return y_pred_org, y_test_t_org


y_pred_org, y_test_t_org = createPredictions_LSTM(model, x_test_t, y_test_t) #IMP!



# def plotLoss():
# Visualize the training data
from matplotlib import pyplot as plt

def plotLoss(history):
    plt.figure()
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper left')
    plt.show()
# Out:
# Saved model `Dec-04-2019_savedLSTM.h5` to disk
# Error is 0.0892558631567398 (32,) (32,)
# [0.972622   0.9748871  0.97688437 0.9783703  0.97988564 0.98065925
#  0.98016423 0.97890115 0.9778106  0.9751026  0.9705497  0.9693036
#  0.96979415 0.97159696 0.97427034]
# [1.34958735 1.3663181  1.3885526  1.41926266 1.37435344 1.33362684
#  1.32790324 1.36202532 1.24634018 1.22531647 1.30963132 1.25734733
#  1.31007153 1.29950476 1.24259779]
# [191.4927  191.69849 191.87994 192.01494 192.1526  192.22289 192.17792
#  192.06317 191.96408 191.71808 191.30444 191.19122 191.2358  191.39958
#  191.64246]
# [225.74000549 227.25999451 229.27999878 232.07000732 227.99000549
#  224.28999329 223.77000427 226.86999512 216.36000061 214.44999695
#  222.11000061 217.36000061 222.1499939  221.19000244 216.02000427]

# %%
plotLoss(history)  # IMP!

# %%
# x_test_t

# %%
def calcError(model, x_test_t, y_test_t, y_pred_org, y_test_t_org):
    y_pred = model.predict(createDataset(x_test_t, batchSize), batch_size=batchSize)
    y_pred = y_pred.flatten()
    y_test_t = createDataset(y_test_t, batchSize)
    error = mean_squared_error(y_test_t, y_pred)
    return ("Error is", error, y_pred.shape, y_test_t.shape)

    print(y_pred[0:15])
    print(y_test_t[0:15])
    y_pred_org = (y_pred * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3] # min_max_scaler.inverse_transform(y_pred)
    y_test_t_org = (y_test_t * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3] # min_max_scaler.inverse_transform(y_test_t)
    print(y_pred_org[0:15])
    print(y_test_t_org[0:15])

# %%
calcError(model, x_test_t, y_test_t, y_pred_org, y_test_t_org)  # IMP!
# Out:
# ('Error is', 0.08512206512233772, (32,), (32,))

# %%
# y_pred

# %%
from matplotlib import pyplot as plt

def plotPrediction(y_pred_org, y_test_t_org):
    stime = time.time()
    
    plt.figure()
    plt.plot(y_pred_org)
    plt.plot(y_test_t_org)
    plt.title('Prediction vs Real Stock Price')
    plt.ylabel('Price')
    plt.xlabel('Days')
    plt.legend(['Prediction', 'Real'], loc='upper left')
    plt.show()
    print("program completed ", time.time() - stime)

# %%
plotPrediction(y_pred_org, y_test_t_org) # IMP!
# Out:
# program completed  0.14200401306152344

# %%
# x_test_t

# %%
# # try with real testing data


# y_pred = lstm_model.predict(createDataset(x_test_t, batchSize), batch_size=batchSize)
# y_pred = y_pred.flatten()
# y_test_t = createDataset(y_test_t, batchSize)
# error = mean_squared_error(y_test_t, y_pred)
# print("Error is", error, y_pred.shape, y_test_t.shape)
# print(y_pred[0:15])
# print(y_test_t[0:15])
# y_pred_org = (y_pred * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3] # min_max_scaler.inverse_transform(y_pred)
# y_test_t_org = (y_test_t * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3] # min_max_scaler.inverse_transform(y_test_t)
# print(y_pred_org[0:15])
# print(y_test_t_org[0:15])

# %%
# is_update_model = True
# if model is None or is_update_model:
#     from keras import backend as K
#     print("Building model...")
#     print("checking if GPU available", K.tensorflow_backend._get_available_gpus())
#     model = create_model()
    
#     es = EarlyStopping(monitor='val_loss', mode='min', verbose=1,
#                        patience=40, min_delta=0.0001)
    
#     mcp = ModelCheckpoint(os.path.join(OUTPUT_PATH,
#                           "best_model.h5"), monitor='val_loss', verbose=1,
#                           save_best_only=True, save_weights_only=False, mode='min', period=1)

#     # Not used here. But leaving it here as a reminder for future
#     r_lr_plat = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=30, 
#                                   verbose=0, mode='auto', min_delta=0.0001, cooldown=0, min_lr=0)
    
#     csv_logger = CSVLogger(os.path.join(OUTPUT_PATH, 'training_log_' + time.ctime().replace(" ","_") + '.log'), append=True)
    
#     history = model.fit(x_t, y_t, epochs=params["epochs"], verbose=2, batch_size=batchSize,
#                         shuffle=False, validation_data=(createDataset(x_val, batchSize),
#                         createDataset(y_val, batchSize)), callbacks=[es, mcp, csv_logger])
    
#     print("saving model...")
#     pickle.dump(model, open("lstm_model", "wb"))

# # model.evaluate(x_test_t, y_test_t, batch_size=batchSize
# y_pred = model.predict(createDataset(x_test_t, batchSize), batch_size=batchSize)
# y_pred = y_pred.flatten()
# y_test_t = createDataset(y_test_t, batchSize)
# error = mean_squared_error(y_test_t, y_pred)
# print("Error is", error, y_pred.shape, y_test_t.shape)
# print(y_pred[0:15])
# print(y_test_t[0:15])

# # convert the predicted value to range of real data
# y_pred_org = (y_pred * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3]
# # min_max_scaler.inverse_transform(y_pred)
# y_test_t_org = (y_test_t * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3]
# # min_max_scaler.inverse_transform(y_test_t)
# print(y_pred_org[0:15])
# print(y_test_t_org[0:15])

# # Visualize the training data
# from matplotlib import pyplot as plt
# plt.figure()
# plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
# plt.title('Model loss')
# plt.ylabel('Loss')
# plt.xlabel('Epoch')
# plt.legend(['Train', 'Test'], loc='upper left')
# #plt.show()
# plt.savefig(os.path.join(OUTPUT_PATH, 'train_vis_BS_'+str(batchSize)+"_"+time.ctime()+'.png'))

# # load the saved best model from above
# saved_model = load_model(os.path.join(OUTPUT_PATH, 'best_model.h5')) # , "lstm_best_7-3-19_12AM",
# print(saved_model)

# y_pred = saved_model.predict(createDataset(x_test_t, batchSize), batch_size=batchSize)
# y_pred = y_pred.flatten()
# y_test_t = createDataset(y_test_t, batchSize)
# error = mean_squared_error(y_test_t, y_pred)
# print("Error is", error, y_pred.shape, y_test_t.shape)
# print(y_pred[0:15])
# print(y_test_t[0:15])
# y_pred_org = (y_pred * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3] # min_max_scaler.inverse_transform(y_pred)
# y_test_t_org = (y_test_t * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3] # min_max_scaler.inverse_transform(y_test_t)
# print(y_pred_org[0:15])
# print(y_test_t_org[0:15])

# # Visualize the prediction
# from matplotlib import pyplot as plt
# plt.figure()
# plt.plot(y_pred_org)
# plt.plot(y_test_t_org)
# plt.title('Prediction vs Real Stock Price')
# plt.ylabel('Price')
# plt.xlabel('Days')
# plt.legend(['Prediction', 'Real'], loc='upper left')
# #plt.show()
# plt.savefig(os.path.join(OUTPUT_PATH, 'pred_vs_real_BS'+str(batchSize)+"_"+time.ctime()+'.png'))
# print_time("program completed ", stime)
