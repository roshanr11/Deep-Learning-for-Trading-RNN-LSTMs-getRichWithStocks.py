# %%
# Author: Roshan Ram
# AndrewID: rram

import yfinance as yfinance

# import module_manager
# module_manager.review()

import yfinance as yf # to pull stock data with yf.download(name, yyyy-mm-dd of opening, yyyy-mm-dd of opening)

import numpy as np # used for everything lol
import pandas as pd # data mainpulation
import matplotlib.pyplot as plt # graphing/plotting
from keras import *

import time, random, copy

#####
import numpy as np
import os
import sys
import time
import pandas as pd 
# from tqdm._tqdm_notebook import tqdm_notebook
import pickle
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout
from keras.layers import LSTM
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger
from keras import optimizers
# from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import logging
####

# %matplotlib inline 
#just to make stuff look nice

# %%
stock = None
while not isinstance(stock, str):
    stock = input("Enter your desired stock. Only alphanumeric characters please.")
openingInp = input("Enter your desired opening date. (yyyy-mm-dd)") #'2016-01-01'
closingInp = input("Enter your desired closing date. (yyyy-mm-dd)") # '2019-08-01'


data = yf.download(stock, openingInp, closingInp)


def getData(app):
    stock = None
#     while not isinstance(stock, str):
    stock = app.getUserInput("Enter your desired stock. Only alphanumeric characters please.")
    openingInp = app.getUserInput("Enter your desired opening date. (yyyy-mm-dd)") #'2016-01-01'
    closingInp = app.getUserInput("Enter your desired closing date. (yyyy-mm-dd)") # '2019-08-01'


    data = yf.download(stock, openingInp, closingInp)
    return data, stock 

# data, stock = getData(app)
# Out:
# Enter your desired stock. Only alphanumeric characters please.AAPL
# Enter your desired opening date. (yyyy-mm-dd)2016-08-01
# Enter your desired closing date. (yyyy-mm-dd)2019-01-01
# [*********************100%***********************]  1 of 1 completed

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# def mainFunc():

TIME_STEPS = 12 # [rram] 
batchSize = 32 # [rram]


#####
params = {
    "batch_size": 20,  # 20<16<10, 25 was a bust
    "epochs": 300,
    "lr": 0.00010000,
    "time_steps": 60
}

iter_changes = "dropout_layers_0.4_0.4"

# INPUT_PATH = PATH_TO_DRIVE_ML_DATA+"/inputs"
OUTPUT_PATH = '~/Desktop'
TIME_STEPS = params["time_steps"]
batchSize = params["batch_size"]
stime = time.time()
###


train_cols = ["Open","High","Low","Close","Volume"]
df_train, df_test = train_test_split(data, train_size=0.8, test_size=0.2, shuffle=False)
print("Train and Test size", len(df_train), len(df_test))
# scale the feature MinMax, build array
x = df_train.loc[:,train_cols].values
min_max_scaler = MinMaxScaler()
x_train = min_max_scaler.fit_transform(x)
x_test = min_max_scaler.transform(df_test.loc[:,train_cols])
# Out:
# Train and Test size 487 122

# %%
def createTimesteps(mat, y_col_index):
    # y_col_index is the index of column that would act as output column
    # total number of time-series samples would be len(mat) - TIME_STEPS
    dim_0 = mat.shape[0] - TIME_STEPS
    dim_1 = mat.shape[1]
    x = np.zeros((dim_0, TIME_STEPS, dim_1))
    y = np.zeros((dim_0,))

    for i in (range(dim_0)):
        x[i] = mat[i:TIME_STEPS+i]
        y[i] = mat[TIME_STEPS+i, y_col_index]
    print("length of time-series i/o",x.shape,y.shape)
    return x, y

def createDataset(mat, batch_size):
    """
    trims dataset to a size that's divisible by batchSize
    """
    no_of_rows_drop = mat.shape[0]%batch_size
    if(no_of_rows_drop > 0):
        return mat[:-no_of_rows_drop]
    else:
        return mat

# %%
x_t, y_t = createTimesteps(x_train, 3)
x_t = createDataset(x_t, batchSize)
y_t = createDataset(y_t, batchSize)
x_temp, y_temp = createTimesteps(x_test, 3)
x_val, x_test_t = np.split(createDataset(x_temp, batchSize),2)
y_val, y_test_t = np.split(createDataset(y_temp, batchSize),2)
# Out:
# length of time-series i/o (427, 60, 5) (427,)
# length of time-series i/o (62, 60, 5) (62,)

# %%
# def create_model():
lstm_model = Sequential()
lstm_model.add(LSTM(100, batch_input_shape=(batchSize, TIME_STEPS, x_t.shape[2]), dropout=0.0, recurrent_dropout=0.0, stateful=True,     kernel_initializer='random_uniform'))
lstm_model.add(Dropout(0.5))
lstm_model.add(Dense(20,activation='relu'))
lstm_model.add(Dense(1,activation='sigmoid'))
optimizer = optimizers.RMSprop(lr=0.00010000)
lstm_model.compile(loss='mean_squared_error', optimizer=optimizer)

# %%
model = lstm_model

# %%
csv_logger = CSVLogger(os.path.join(OUTPUT_PATH, 'your_log_name' + '.log'), append=True)

# epochs = params['epochs']


# NOTE TO SELF CHANGE EPOCHS BACK to 300
history = model.fit(x_t, y_t, epochs=300, verbose=2, batch_size=batchSize,
                    shuffle=False, validation_data=(createDataset(x_val, batchSize),
                    createDataset(y_val, batchSize))) #callbacks=[csv_logger])

# history = model.fit(x_t, y_t, epochs=params["epochs"], verbose=2, batch_size=batchSize,
#                         shuffle=False, validation_data=(createDataset(x_val, batchSize),
#                         createDataset(y_val, batchSize)), callbacks=[es, mcp, csv_logger])
# Out:
# Train on 420 samples, validate on 20 samples
# Epoch 1/300
#  - 1s - loss: 0.0605 - val_loss: 0.5394
# Epoch 2/300
#  - 1s - loss: 0.0534 - val_loss: 0.4527
# Epoch 3/300
#  - 1s - loss: 0.0484 - val_loss: 0.3674
# Epoch 4/300
#  - 1s - loss: 0.0445 - val_loss: 0.2869
# Epoch 5/300
#  - 1s - loss: 0.0417 - val_loss: 0.2263
# Epoch 6/300
#  - 1s - loss: 0.0413 - val_loss: 0.1916
# Epoch 7/300
#  - 1s - loss: 0.0407 - val_loss: 0.1715
# Epoch 8/300
#  - 1s - loss: 0.0396 - val_loss: 0.1572
# Epoch 9/300
#  - 1s - loss: 0.0386 - val_loss: 0.1481
# Epoch 10/300
#  - 1s - loss: 0.0371 - val_loss: 0.1347
# Epoch 11/300
#  - 1s - loss: 0.0358 - val_loss: 0.1332
# Epoch 12/300
#  - 1s - loss: 0.0337 - val_loss: 0.1265
# Epoch 13/300
#  - 1s - loss: 0.0327 - val_loss: 0.1255
# Epoch 14/300
#  - 1s - loss: 0.0319 - val_loss: 0.1223
# Epoch 15/300
#  - 1s - loss: 0.0315 - val_loss: 0.1202
# Epoch 16/300
#  - 1s - loss: 0.0309 - val_loss: 0.1193
# Epoch 17/300
#  - 1s - loss: 0.0303 - val_loss: 0.1179
# Epoch 18/300
#  - 1s - loss: 0.0292 - val_loss: 0.1169
# Epoch 19/300
#  - 1s - loss: 0.0284 - val_loss: 0.1168
# Epoch 20/300
#  - 1s - loss: 0.0280 - val_loss: 0.1169
# Epoch 21/300
#  - 1s - loss: 0.0269 - val_loss: 0.1166
# Epoch 22/300
#  - 1s - loss: 0.0266 - val_loss: 0.1171
# Epoch 23/300
#  - 1s - loss: 0.0256 - val_loss: 0.1178
# Epoch 24/300
#  - 1s - loss: 0.0249 - val_loss: 0.1194
# Epoch 25/300
#  - 1s - loss: 0.0234 - val_loss: 0.1195
# Epoch 26/300
#  - 1s - loss: 0.0228 - val_loss: 0.1211
# Epoch 27/300
#  - 1s - loss: 0.0217 - val_loss: 0.1228
# Epoch 28/300
#  - 1s - loss: 0.0205 - val_loss: 0.1240
# Epoch 29/300
#  - 1s - loss: 0.0193 - val_loss: 0.1256
# Epoch 30/300
#  - 1s - loss: 0.0184 - val_loss: 0.1276
# Epoch 31/300
#  - 1s - loss: 0.0170 - val_loss: 0.1279
# Epoch 32/300
#  - 1s - loss: 0.0162 - val_loss: 0.1291
# Epoch 33/300
#  - 1s - loss: 0.0149 - val_loss: 0.1328
# Epoch 34/300
#  - 1s - loss: 0.0143 - val_loss: 0.1337
# Epoch 35/300
#  - 1s - loss: 0.0137 - val_loss: 0.1327
# Epoch 36/300
#  - 1s - loss: 0.0132 - val_loss: 0.1321
# Epoch 37/300
#  - 1s - loss: 0.0132 - val_loss: 0.1319
# Epoch 38/300
#  - 1s - loss: 0.0122 - val_loss: 0.1314
# Epoch 39/300
#  - 1s - loss: 0.0116 - val_loss: 0.1288
# Epoch 40/300
#  - 1s - loss: 0.0112 - val_loss: 0.1280
# Epoch 41/300
#  - 1s - loss: 0.0115 - val_loss: 0.1281
# Epoch 42/300
#  - 1s - loss: 0.0107 - val_loss: 0.1272
# Epoch 43/300
#  - 1s - loss: 0.0107 - val_loss: 0.1261
# Epoch 44/300
#  - 1s - loss: 0.0105 - val_loss: 0.1246
# Epoch 45/300
#  - 1s - loss: 0.0105 - val_loss: 0.1236
# Epoch 46/300
#  - 1s - loss: 0.0102 - val_loss: 0.1227
# Epoch 47/300
#  - 1s - loss: 0.0098 - val_loss: 0.1216
# Epoch 48/300
#  - 1s - loss: 0.0096 - val_loss: 0.1216
# Epoch 49/300
#  - 1s - loss: 0.0094 - val_loss: 0.1200
# Epoch 50/300
#  - 1s - loss: 0.0090 - val_loss: 0.1206
# Epoch 51/300
#  - 1s - loss: 0.0090 - val_loss: 0.1180
# Epoch 52/300
#  - 1s - loss: 0.0084 - val_loss: 0.1184
# Epoch 53/300
#  - 1s - loss: 0.0086 - val_loss: 0.1162
# Epoch 54/300
#  - 1s - loss: 0.0091 - val_loss: 0.1171
# Epoch 55/300
#  - 1s - loss: 0.0081 - val_loss: 0.1160
# Epoch 56/300
#  - 1s - loss: 0.0080 - val_loss: 0.1155
# Epoch 57/300
#  - 1s - loss: 0.0082 - val_loss: 0.1158
# Epoch 58/300
#  - 1s - loss: 0.0078 - val_loss: 0.1150
# Epoch 59/300
#  - 1s - loss: 0.0082 - val_loss: 0.1156
# Epoch 60/300
#  - 1s - loss: 0.0083 - val_loss: 0.1145
# Epoch 61/300
#  - 1s - loss: 0.0079 - val_loss: 0.1152
# Epoch 62/300
#  - 1s - loss: 0.0074 - val_loss: 0.1131
# Epoch 63/300
#  - 1s - loss: 0.0081 - val_loss: 0.1137
# Epoch 64/300
#  - 1s - loss: 0.0079 - val_loss: 0.1141
# Epoch 65/300
#  - 1s - loss: 0.0075 - val_loss: 0.1138
# Epoch 66/300
#  - 1s - loss: 0.0076 - val_loss: 0.1132
# Epoch 67/300
#  - 1s - loss: 0.0072 - val_loss: 0.1137
# Epoch 68/300
#  - 1s - loss: 0.0070 - val_loss: 0.1137
# Epoch 69/300
#  - 1s - loss: 0.0072 - val_loss: 0.1134
# Epoch 70/300
#  - 1s - loss: 0.0071 - val_loss: 0.1141
# Epoch 71/300
#  - 1s - loss: 0.0068 - val_loss: 0.1137
# Epoch 72/300
#  - 1s - loss: 0.0071 - val_loss: 0.1130
# Epoch 73/300
#  - 1s - loss: 0.0069 - val_loss: 0.1137
# Epoch 74/300
#  - 1s - loss: 0.0068 - val_loss: 0.1131
# Epoch 75/300
#  - 1s - loss: 0.0069 - val_loss: 0.1137
# Epoch 76/300
#  - 1s - loss: 0.0066 - val_loss: 0.1136
# Epoch 77/300
#  - 1s - loss: 0.0063 - val_loss: 0.1142
# Epoch 78/300
#  - 1s - loss: 0.0067 - val_loss: 0.1132
# Epoch 79/300
#  - 1s - loss: 0.0068 - val_loss: 0.1140
# Epoch 80/300
#  - 1s - loss: 0.0062 - val_loss: 0.1141
# Epoch 81/300
#  - 1s - loss: 0.0062 - val_loss: 0.1125
# Epoch 82/300
#  - 1s - loss: 0.0065 - val_loss: 0.1132
# Epoch 83/300
#  - 1s - loss: 0.0060 - val_loss: 0.1142
# Epoch 84/300
#  - 1s - loss: 0.0067 - val_loss: 0.1144
# Epoch 85/300
#  - 1s - loss: 0.0059 - val_loss: 0.1137
# Epoch 86/300
#  - 1s - loss: 0.0060 - val_loss: 0.1141
# Epoch 87/300
#  - 1s - loss: 0.0063 - val_loss: 0.1139
# Epoch 88/300
#  - 1s - loss: 0.0057 - val_loss: 0.1142
# Epoch 89/300
#  - 1s - loss: 0.0061 - val_loss: 0.1136
# Epoch 90/300
#  - 1s - loss: 0.0054 - val_loss: 0.1141
# Epoch 91/300
#  - 1s - loss: 0.0060 - val_loss: 0.1147
# Epoch 92/300
#  - 1s - loss: 0.0059 - val_loss: 0.1144
# Epoch 93/300
#  - 1s - loss: 0.0058 - val_loss: 0.1161
# Epoch 94/300
#  - 1s - loss: 0.0057 - val_loss: 0.1162
# Epoch 95/300
#  - 1s - loss: 0.0060 - val_loss: 0.1171
# Epoch 96/300
#  - 1s - loss: 0.0055 - val_loss: 0.1164
# Epoch 97/300
#  - 1s - loss: 0.0058 - val_loss: 0.1168
# Epoch 98/300
#  - 1s - loss: 0.0055 - val_loss: 0.1173
# Epoch 99/300
#  - 1s - loss: 0.0057 - val_loss: 0.1166
# Epoch 100/300
#  - 1s - loss: 0.0061 - val_loss: 0.1166
# Epoch 101/300
#  - 1s - loss: 0.0054 - val_loss: 0.1164
# Epoch 102/300
#  - 1s - loss: 0.0054 - val_loss: 0.1163
# Epoch 103/300
#  - 1s - loss: 0.0055 - val_loss: 0.1162
# Epoch 104/300
#  - 1s - loss: 0.0054 - val_loss: 0.1173
# Epoch 105/300
#  - 1s - loss: 0.0059 - val_loss: 0.1180
# Epoch 106/300
#  - 1s - loss: 0.0057 - val_loss: 0.1168
# Epoch 107/300
#  - 1s - loss: 0.0060 - val_loss: 0.1172
# Epoch 108/300
#  - 1s - loss: 0.0056 - val_loss: 0.1172
# Epoch 109/300
#  - 1s - loss: 0.0054 - val_loss: 0.1174
# Epoch 110/300
#  - 1s - loss: 0.0055 - val_loss: 0.1179
# Epoch 111/300
#  - 1s - loss: 0.0055 - val_loss: 0.1189
# Epoch 112/300
#  - 1s - loss: 0.0057 - val_loss: 0.1179
# Epoch 113/300
#  - 1s - loss: 0.0052 - val_loss: 0.1183
# Epoch 114/300
#  - 1s - loss: 0.0054 - val_loss: 0.1175
# Epoch 115/300
#  - 1s - loss: 0.0055 - val_loss: 0.1190
# Epoch 116/300
#  - 1s - loss: 0.0054 - val_loss: 0.1182
# Epoch 117/300
#  - 1s - loss: 0.0052 - val_loss: 0.1174
# Epoch 118/300
#  - 1s - loss: 0.0053 - val_loss: 0.1172
# Epoch 119/300
#  - 1s - loss: 0.0056 - val_loss: 0.1181
# Epoch 120/300
#  - 1s - loss: 0.0054 - val_loss: 0.1185
# Epoch 121/300
#  - 1s - loss: 0.0051 - val_loss: 0.1175
# Epoch 122/300
#  - 1s - loss: 0.0053 - val_loss: 0.1186
# Epoch 123/300
#  - 1s - loss: 0.0054 - val_loss: 0.1186
# Epoch 124/300
#  - 1s - loss: 0.0051 - val_loss: 0.1179
# Epoch 125/300
#  - 1s - loss: 0.0053 - val_loss: 0.1182
# Epoch 126/300
#  - 1s - loss: 0.0052 - val_loss: 0.1181
# Epoch 127/300
#  - 1s - loss: 0.0052 - val_loss: 0.1180
# Epoch 128/300
#  - 1s - loss: 0.0054 - val_loss: 0.1177
# Epoch 129/300
#  - 1s - loss: 0.0051 - val_loss: 0.1169
# Epoch 130/300
#  - 1s - loss: 0.0049 - val_loss: 0.1170
# Epoch 131/300
#  - 1s - loss: 0.0056 - val_loss: 0.1188
# Epoch 132/300
#  - 1s - loss: 0.0049 - val_loss: 0.1191
# Epoch 133/300
#  - 1s - loss: 0.0049 - val_loss: 0.1185
# Epoch 134/300
#  - 1s - loss: 0.0053 - val_loss: 0.1186
# Epoch 135/300
#  - 1s - loss: 0.0052 - val_loss: 0.1185
# Epoch 136/300
#  - 1s - loss: 0.0050 - val_loss: 0.1176
# Epoch 137/300
#  - 1s - loss: 0.0051 - val_loss: 0.1184
# Epoch 138/300
#  - 1s - loss: 0.0051 - val_loss: 0.1173
# Epoch 139/300
#  - 1s - loss: 0.0049 - val_loss: 0.1183
# Epoch 140/300
#  - 1s - loss: 0.0052 - val_loss: 0.1178
# Epoch 141/300
#  - 1s - loss: 0.0050 - val_loss: 0.1166
# Epoch 142/300
#  - 1s - loss: 0.0050 - val_loss: 0.1170
# Epoch 143/300
#  - 1s - loss: 0.0043 - val_loss: 0.1168
# Epoch 144/300
#  - 1s - loss: 0.0047 - val_loss: 0.1163
# Epoch 145/300
#  - 1s - loss: 0.0050 - val_loss: 0.1169
# Epoch 146/300
#  - 1s - loss: 0.0049 - val_loss: 0.1162
# Epoch 147/300
#  - 1s - loss: 0.0042 - val_loss: 0.1168
# Epoch 148/300
#  - 1s - loss: 0.0046 - val_loss: 0.1158
# Epoch 149/300
#  - 1s - loss: 0.0050 - val_loss: 0.1156
# Epoch 150/300
#  - 1s - loss: 0.0044 - val_loss: 0.1155
# Epoch 151/300
#  - 1s - loss: 0.0047 - val_loss: 0.1177
# Epoch 152/300
#  - 1s - loss: 0.0045 - val_loss: 0.1168
# Epoch 153/300
#  - 1s - loss: 0.0048 - val_loss: 0.1169
# Epoch 154/300
#  - 1s - loss: 0.0047 - val_loss: 0.1164
# Epoch 155/300
#  - 1s - loss: 0.0043 - val_loss: 0.1152
# Epoch 156/300
#  - 1s - loss: 0.0046 - val_loss: 0.1153
# Epoch 157/300
#  - 1s - loss: 0.0047 - val_loss: 0.1165
# Epoch 158/300
#  - 1s - loss: 0.0043 - val_loss: 0.1145
# Epoch 159/300
#  - 1s - loss: 0.0046 - val_loss: 0.1154
# Epoch 160/300
#  - 1s - loss: 0.0046 - val_loss: 0.1156
# Epoch 161/300
#  - 1s - loss: 0.0043 - val_loss: 0.1147
# Epoch 162/300
#  - 1s - loss: 0.0042 - val_loss: 0.1150
# Epoch 163/300
#  - 1s - loss: 0.0043 - val_loss: 0.1149
# Epoch 164/300
#  - 1s - loss: 0.0043 - val_loss: 0.1153
# Epoch 165/300
#  - 1s - loss: 0.0044 - val_loss: 0.1146
# Epoch 166/300
#  - 1s - loss: 0.0046 - val_loss: 0.1158
# Epoch 167/300
#  - 1s - loss: 0.0045 - val_loss: 0.1157
# Epoch 168/300
#  - 1s - loss: 0.0042 - val_loss: 0.1143
# Epoch 169/300
#  - 1s - loss: 0.0043 - val_loss: 0.1134
# Epoch 170/300
#  - 1s - loss: 0.0042 - val_loss: 0.1133
# Epoch 171/300
#  - 1s - loss: 0.0041 - val_loss: 0.1129
# Epoch 172/300
#  - 1s - loss: 0.0040 - val_loss: 0.1143
# Epoch 173/300
#  - 1s - loss: 0.0043 - val_loss: 0.1138
# Epoch 174/300
#  - 1s - loss: 0.0041 - val_loss: 0.1143
# Epoch 175/300
#  - 1s - loss: 0.0041 - val_loss: 0.1138
# Epoch 176/300
#  - 1s - loss: 0.0041 - val_loss: 0.1140
# Epoch 177/300
#  - 1s - loss: 0.0041 - val_loss: 0.1143
# Epoch 178/300
#  - 1s - loss: 0.0039 - val_loss: 0.1124
# Epoch 179/300
#  - 1s - loss: 0.0040 - val_loss: 0.1139
# Epoch 180/300
#  - 1s - loss: 0.0042 - val_loss: 0.1133
# Epoch 181/300
#  - 1s - loss: 0.0042 - val_loss: 0.1136
# Epoch 182/300
#  - 1s - loss: 0.0039 - val_loss: 0.1138
# Epoch 183/300
#  - 1s - loss: 0.0042 - val_loss: 0.1144
# Epoch 184/300
#  - 1s - loss: 0.0040 - val_loss: 0.1135
# Epoch 185/300
#  - 1s - loss: 0.0038 - val_loss: 0.1129
# Epoch 186/300
#  - 1s - loss: 0.0040 - val_loss: 0.1121
# Epoch 187/300
#  - 1s - loss: 0.0042 - val_loss: 0.1130
# Epoch 188/300
#  - 1s - loss: 0.0039 - val_loss: 0.1141
# Epoch 189/300
#  - 1s - loss: 0.0038 - val_loss: 0.1130
# Epoch 190/300
#  - 1s - loss: 0.0040 - val_loss: 0.1135
# Epoch 191/300
#  - 1s - loss: 0.0038 - val_loss: 0.1132
# Epoch 192/300
#  - 1s - loss: 0.0037 - val_loss: 0.1137
# Epoch 193/300
#  - 1s - loss: 0.0042 - val_loss: 0.1132
# Epoch 194/300
#  - 1s - loss: 0.0035 - val_loss: 0.1147
# Epoch 195/300
#  - 1s - loss: 0.0038 - val_loss: 0.1158
# Epoch 196/300
#  - 1s - loss: 0.0037 - val_loss: 0.1153
# Epoch 197/300
#  - 1s - loss: 0.0037 - val_loss: 0.1151
# Epoch 198/300
#  - 1s - loss: 0.0038 - val_loss: 0.1153
# Epoch 199/300
#  - 1s - loss: 0.0036 - val_loss: 0.1140
# Epoch 200/300
#  - 1s - loss: 0.0039 - val_loss: 0.1152
# Epoch 201/300
#  - 1s - loss: 0.0042 - val_loss: 0.1137
# Epoch 202/300
#  - 1s - loss: 0.0039 - val_loss: 0.1155
# Epoch 203/300
#  - 1s - loss: 0.0037 - val_loss: 0.1157
# Epoch 204/300
#  - 1s - loss: 0.0041 - val_loss: 0.1163
# Epoch 205/300
#  - 1s - loss: 0.0039 - val_loss: 0.1160
# Epoch 206/300
#  - 1s - loss: 0.0040 - val_loss: 0.1159
# Epoch 207/300
#  - 1s - loss: 0.0035 - val_loss: 0.1163
# Epoch 208/300
#  - 1s - loss: 0.0038 - val_loss: 0.1170
# Epoch 209/300
#  - 1s - loss: 0.0038 - val_loss: 0.1174
# Epoch 210/300
#  - 1s - loss: 0.0035 - val_loss: 0.1159
# Epoch 211/300
#  - 1s - loss: 0.0039 - val_loss: 0.1173
# Epoch 212/300
#  - 1s - loss: 0.0038 - val_loss: 0.1177
# Epoch 213/300
#  - 1s - loss: 0.0038 - val_loss: 0.1181
# Epoch 214/300
#  - 1s - loss: 0.0037 - val_loss: 0.1161
# Epoch 215/300
#  - 1s - loss: 0.0038 - val_loss: 0.1191
# Epoch 216/300
#  - 1s - loss: 0.0037 - val_loss: 0.1199
# Epoch 217/300
#  - 1s - loss: 0.0035 - val_loss: 0.1217
# Epoch 218/300
#  - 1s - loss: 0.0037 - val_loss: 0.1218
# Epoch 219/300
#  - 1s - loss: 0.0037 - val_loss: 0.1206
# Epoch 220/300
#  - 1s - loss: 0.0036 - val_loss: 0.1223
# Epoch 221/300
#  - 1s - loss: 0.0035 - val_loss: 0.1215
# Epoch 222/300
#  - 1s - loss: 0.0038 - val_loss: 0.1215
# Epoch 223/300
#  - 1s - loss: 0.0038 - val_loss: 0.1222
# Epoch 224/300
#  - 1s - loss: 0.0036 - val_loss: 0.1230
# Epoch 225/300
#  - 1s - loss: 0.0035 - val_loss: 0.1244
# Epoch 226/300
#  - 1s - loss: 0.0033 - val_loss: 0.1228
# Epoch 227/300
#  - 1s - loss: 0.0037 - val_loss: 0.1241
# Epoch 228/300
#  - 1s - loss: 0.0035 - val_loss: 0.1242
# Epoch 229/300
#  - 1s - loss: 0.0036 - val_loss: 0.1260
# Epoch 230/300
#  - 1s - loss: 0.0037 - val_loss: 0.1271
# Epoch 231/300
#  - 1s - loss: 0.0035 - val_loss: 0.1293
# Epoch 232/300
#  - 1s - loss: 0.0034 - val_loss: 0.1259
# Epoch 233/300
#  - 1s - loss: 0.0038 - val_loss: 0.1259
# Epoch 234/300
#  - 1s - loss: 0.0035 - val_loss: 0.1278
# Epoch 235/300
#  - 1s - loss: 0.0033 - val_loss: 0.1272
# Epoch 236/300
#  - 1s - loss: 0.0035 - val_loss: 0.1285
# Epoch 237/300
#  - 1s - loss: 0.0038 - val_loss: 0.1292
# Epoch 238/300
#  - 1s - loss: 0.0038 - val_loss: 0.1323
# Epoch 239/300
#  - 1s - loss: 0.0035 - val_loss: 0.1316
# Epoch 240/300
#  - 1s - loss: 0.0033 - val_loss: 0.1300
# Epoch 241/300
#  - 1s - loss: 0.0035 - val_loss: 0.1333
# Epoch 242/300
#  - 1s - loss: 0.0035 - val_loss: 0.1325
# Epoch 243/300
#  - 1s - loss: 0.0039 - val_loss: 0.1337
# Epoch 244/300
#  - 1s - loss: 0.0036 - val_loss: 0.1329
# Epoch 245/300
#  - 1s - loss: 0.0036 - val_loss: 0.1320
# Epoch 246/300
#  - 1s - loss: 0.0040 - val_loss: 0.1306
# Epoch 247/300
#  - 1s - loss: 0.0039 - val_loss: 0.1316
# Epoch 248/300
#  - 1s - loss: 0.0036 - val_loss: 0.1258
# Epoch 249/300
#  - 1s - loss: 0.0035 - val_loss: 0.1302
# Epoch 250/300
#  - 1s - loss: 0.0032 - val_loss: 0.1303
# Epoch 251/300
#  - 1s - loss: 0.0036 - val_loss: 0.1298
# Epoch 252/300
#  - 1s - loss: 0.0035 - val_loss: 0.1309
# Epoch 253/300
#  - 1s - loss: 0.0034 - val_loss: 0.1306
# Epoch 254/300
#  - 1s - loss: 0.0035 - val_loss: 0.1348
# Epoch 255/300
#  - 1s - loss: 0.0034 - val_loss: 0.1362
# Epoch 256/300
#  - 1s - loss: 0.0043 - val_loss: 0.1393
# Epoch 257/300
#  - 1s - loss: 0.0033 - val_loss: 0.1367
# Epoch 258/300
#  - 1s - loss: 0.0033 - val_loss: 0.1410
# Epoch 259/300
#  - 1s - loss: 0.0034 - val_loss: 0.1366
# Epoch 260/300
#  - 1s - loss: 0.0035 - val_loss: 0.1409
# Epoch 261/300
#  - 1s - loss: 0.0037 - val_loss: 0.1389
# Epoch 262/300
#  - 1s - loss: 0.0038 - val_loss: 0.1420
# Epoch 263/300
#  - 1s - loss: 0.0030 - val_loss: 0.1402
# Epoch 264/300
#  - 1s - loss: 0.0036 - val_loss: 0.1428
# Epoch 265/300
#  - 1s - loss: 0.0037 - val_loss: 0.1422
# Epoch 266/300
#  - 1s - loss: 0.0035 - val_loss: 0.1402
# Epoch 267/300
#  - 1s - loss: 0.0034 - val_loss: 0.1406
# Epoch 268/300
#  - 1s - loss: 0.0033 - val_loss: 0.1430
# Epoch 269/300
#  - 1s - loss: 0.0033 - val_loss: 0.1432
# Epoch 270/300
#  - 1s - loss: 0.0034 - val_loss: 0.1452
# Epoch 271/300
#  - 1s - loss: 0.0034 - val_loss: 0.1459
# Epoch 272/300
#  - 1s - loss: 0.0037 - val_loss: 0.1527
# Epoch 273/300
#  - 1s - loss: 0.0031 - val_loss: 0.1555
# Epoch 274/300
#  - 1s - loss: 0.0036 - val_loss: 0.1562
# Epoch 275/300
#  - 1s - loss: 0.0034 - val_loss: 0.1497
# Epoch 276/300
#  - 1s - loss: 0.0036 - val_loss: 0.1620
# Epoch 277/300
#  - 1s - loss: 0.0033 - val_loss: 0.1579
# Epoch 278/300
#  - 1s - loss: 0.0039 - val_loss: 0.1581
# Epoch 279/300
#  - 1s - loss: 0.0032 - val_loss: 0.1533
# Epoch 280/300
#  - 1s - loss: 0.0033 - val_loss: 0.1551
# Epoch 281/300
#  - 1s - loss: 0.0037 - val_loss: 0.1572
# Epoch 282/300
#  - 1s - loss: 0.0036 - val_loss: 0.1631
# Epoch 283/300
#  - 1s - loss: 0.0036 - val_loss: 0.1663
# Epoch 284/300
#  - 1s - loss: 0.0036 - val_loss: 0.1643
# Epoch 285/300
#  - 1s - loss: 0.0035 - val_loss: 0.1678
# Epoch 286/300
#  - 1s - loss: 0.0032 - val_loss: 0.1700
# Epoch 287/300
#  - 1s - loss: 0.0037 - val_loss: 0.1604
# Epoch 288/300
#  - 1s - loss: 0.0036 - val_loss: 0.1774
# Epoch 289/300
#  - 1s - loss: 0.0033 - val_loss: 0.1717
# Epoch 290/300
#  - 1s - loss: 0.0035 - val_loss: 0.1737
# Epoch 291/300
#  - 1s - loss: 0.0034 - val_loss: 0.1743
# Epoch 292/300
#  - 1s - loss: 0.0034 - val_loss: 0.1746
# Epoch 293/300
#  - 1s - loss: 0.0034 - val_loss: 0.1865
# Epoch 294/300
#  - 1s - loss: 0.0030 - val_loss: 0.1771
# Epoch 295/300
#  - 1s - loss: 0.0039 - val_loss: 0.1677
# Epoch 296/300
#  - 1s - loss: 0.0044 - val_loss: 0.1836
# Epoch 297/300
#  - 1s - loss: 0.0035 - val_loss: 0.1700
# Epoch 298/300
#  - 1s - loss: 0.0028 - val_loss: 0.1709
# Epoch 299/300
#  - 1s - loss: 0.0035 - val_loss: 0.1678
# Epoch 300/300
#  - 1s - loss: 0.0032 - val_loss: 0.1717

# %%
# update: SAVED MODEL!!! IMPORTANT WILL SAVE TIME ON FRONTEND FOR USER [12/4/19]
fileName = 'savedLSTM.h5'
model.save(fileName)
print(f"Saved model `{fileName}` to disk")
#######################################################################################################


y_pred = model.predict(createDataset(x_test_t, batchSize), batch_size=batchSize)
y_pred = y_pred.flatten()
y_test_t = createDataset(y_test_t, batchSize)
error = mean_squared_error(y_test_t, y_pred)
print("Error is", error, y_pred.shape, y_test_t.shape)
print(y_pred[0:15])
print(y_test_t[0:15])

# convert the predicted value to range of real data
y_pred_org = (y_pred * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3]
# min_max_scaler.inverse_transform(y_pred)
y_test_t_org = (y_test_t * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3]
# min_max_scaler.inverse_transform(y_test_t)
print(y_pred_org[0:15])
print(y_test_t_org[0:15])


# def plotLoss():
# Visualize the training data
from matplotlib import pyplot as plt
plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
#plt.show()
# Out:
# Saved model `savedLSTM.h5` to disk
# Error is 0.15465789603458957 (20,) (20,)
# [0.66360873 0.6332941  0.59963953 0.5723264  0.55270416 0.5288108
#  0.48941365 0.46116036 0.43590972 0.4070894  0.38261345 0.36839542
#  0.36100388 0.3554989  0.35805905]
# [0.98073748 0.92096871 0.9717117  0.99504681 0.91062196 0.81287837
#  0.81067697 0.76125478 0.78690148 0.78271887 0.85646677 0.84116684
#  0.83048988 0.89917459 0.80968637]
# [163.41885 160.66476 157.60724 155.12585 153.34317 151.17245 147.59323
#  145.02641 142.73239 140.11407 137.89043 136.59872 135.9272  135.42708
#  135.65967]
# [192.22999573 186.80000305 191.41000366 193.52999878 185.86000061
#  176.97999573 176.77999878 172.28999329 174.61999512 174.24000549
#  180.94000244 179.55000305 178.58000183 184.82000732 176.69000244]

# %%
x_test_t
# Out:
# array([[[1.26188662, 1.28232365, 1.25325615, 1.23643381, 0.18716514],
#         [1.24767739, 1.25983281, 1.24123342, 1.23181065, 0.14609523],
#         [1.218166  , 1.25045213, 1.23911828, 1.23192083, 0.07503997],
#         ...,
#         [1.17313364, 1.17992766, 1.16019146, 1.15971392, 0.13816361],
#         [1.12471313, 1.13347647, 1.11009684, 1.11546511, 0.22773958],
#         [1.05312057, 1.06385635, 1.01591888, 1.00209139, 0.39458716]],
#
#        [[1.24767739, 1.25983281, 1.24123342, 1.23181065, 0.14609523],
#         [1.218166  , 1.25045213, 1.23911828, 1.23192083, 0.07503997],
#         [1.22417745, 1.25825053, 1.24757882, 1.23676401, 0.0736978 ],
#         ...,
#         [1.12471313, 1.13347647, 1.11009684, 1.11546511, 0.22773958],
#         [1.05312057, 1.06385635, 1.01591888, 1.00209139, 0.39458716],
#         [0.97256537, 1.03367988, 0.98986971, 0.98073748, 0.35227656]],
#
#        [[1.218166  , 1.25045213, 1.23911828, 1.23192083, 0.07503997],
#         [1.22417745, 1.25825053, 1.24757882, 1.23676401, 0.0736978 ],
#         [1.24549139, 1.25655513, 1.25325615, 1.24413878, 0.06965041],
#         ...,
#         [1.05312057, 1.06385635, 1.01591888, 1.00209139, 0.39458716],
#         [0.97256537, 1.03367988, 0.98986971, 0.98073748, 0.35227656],
#         [0.9973767 , 1.00316454, 0.92842026, 0.92096871, 0.49075258]],
#
#        ...,
#
#        [[1.32440713, 1.36437621, 1.34709999, 1.3408916 , 0.18610554],
#         [1.33500923, 1.35759495, 1.35244354, 1.34958735, 0.11395486],
#         [1.36954857, 1.39805609, 1.37838144, 1.3663181 , 0.12063485],
#         ...,
#         [0.6924254 , 0.69767178, 0.62963371, 0.63577329, 0.37381093],
#         [0.63121646, 0.63731919, 0.58744298, 0.59108427, 0.53027139],
#         [0.59252378, 0.59267637, 0.52432378, 0.52394055, 0.83841861]],
#
#        [[1.33500923, 1.35759495, 1.35244354, 1.34958735, 0.11395486],
#         [1.36954857, 1.39805609, 1.37838144, 1.3663181 , 0.12063485],
#         [1.36189749, 1.40461127, 1.38149843, 1.3885526 , 0.1324487 ],
#         ...,
#         [0.63121646, 0.63731919, 0.58744298, 0.59108427, 0.53027139],
#         [0.59252378, 0.59267637, 0.52432378, 0.52394055, 0.83841861],
#         [0.49732204, 0.51797021, 0.49048198, 0.48101272, 0.25563158]],
#
#        [[1.36954857, 1.39805609, 1.37838144, 1.3663181 , 0.12063485],
#         [1.36189749, 1.40461127, 1.38149843, 1.3885526 , 0.1324487 ],
#         [1.39250196, 1.44382918, 1.41656459, 1.41926266, 0.17091885],
#         ...,
#         [0.59252378, 0.59267637, 0.52432378, 0.52394055, 0.83841861],
#         [0.49732204, 0.51797021, 0.49048198, 0.48101272, 0.25563158],
#         [0.49896166, 0.58216543, 0.49192922, 0.59482666, 0.46867995]]])

# %%
y_pred = lstm_model.predict(createDataset(x_test_t, batchSize), batch_size=batchSize)
y_pred = y_pred.flatten()
y_test_t = createDataset(y_test_t, batchSize)
error = mean_squared_error(y_test_t, y_pred)
print("Error is", error, y_pred.shape, y_test_t.shape)
print(y_pred[0:15])
print(y_test_t[0:15])
y_pred_org = (y_pred * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3] # min_max_scaler.inverse_transform(y_pred)
y_test_t_org = (y_test_t * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3] # min_max_scaler.inverse_transform(y_test_t)
print(y_pred_org[0:15])
print(y_test_t_org[0:15])
# Out:
# Error is 0.16385740309496438 (20,) (20,)
# [0.65493387 0.62384474 0.59102213 0.5628488  0.54272264 0.5183889
#  0.4784999  0.4499776  0.4234339  0.39447534 0.3699788  0.35630822
#  0.34881598 0.3430659  0.34515572]
# [0.98073748 0.92096871 0.9717117  0.99504681 0.91062196 0.81287837
#  0.81067697 0.76125478 0.78690148 0.78271887 0.85646677 0.84116684
#  0.83048988 0.89917459 0.80968637]
# [162.63074 159.80629 156.82436 154.2648  152.43634 150.22563 146.60172
#  144.01047 141.59897 138.96808 136.74257 135.5006  134.81993 134.29753
#  134.4874 ]
# [192.22999573 186.80000305 191.41000366 193.52999878 185.86000061
#  176.97999573 176.77999878 172.28999329 174.61999512 174.24000549
#  180.94000244 179.55000305 178.58000183 184.82000732 176.69000244]

# %%
y_pred
# Out:
# array([0.65493387, 0.62384474, 0.59102213, 0.5628488 , 0.54272264,
#        0.5183889 , 0.4784999 , 0.4499776 , 0.4234339 , 0.39447534,
#        0.3699788 , 0.35630822, 0.34881598, 0.3430659 , 0.34515572,
#        0.3448379 , 0.34024575, 0.33643937, 0.3286438 , 0.32645133],
#       dtype=float32)

# %%
from matplotlib import pyplot as plt

# def plotPrediction():
plt.figure()
plt.plot(y_pred_org)
plt.plot(y_test_t_org)
plt.title('Prediction vs Real Stock Price')
plt.ylabel('Price')
plt.xlabel('Days')
plt.legend(['Prediction', 'Real'], loc='upper left')
plt.show()
print("program completed ", time.time() - stime)
# Out:
# program completed  186.79761505126953

# %%
x_test_t
# Out:
# array([[[1.26188662, 1.28232365, 1.25325615, 1.23643381, 0.18716514],
#         [1.24767739, 1.25983281, 1.24123342, 1.23181065, 0.14609523],
#         [1.218166  , 1.25045213, 1.23911828, 1.23192083, 0.07503997],
#         ...,
#         [1.17313364, 1.17992766, 1.16019146, 1.15971392, 0.13816361],
#         [1.12471313, 1.13347647, 1.11009684, 1.11546511, 0.22773958],
#         [1.05312057, 1.06385635, 1.01591888, 1.00209139, 0.39458716]],
#
#        [[1.24767739, 1.25983281, 1.24123342, 1.23181065, 0.14609523],
#         [1.218166  , 1.25045213, 1.23911828, 1.23192083, 0.07503997],
#         [1.22417745, 1.25825053, 1.24757882, 1.23676401, 0.0736978 ],
#         ...,
#         [1.12471313, 1.13347647, 1.11009684, 1.11546511, 0.22773958],
#         [1.05312057, 1.06385635, 1.01591888, 1.00209139, 0.39458716],
#         [0.97256537, 1.03367988, 0.98986971, 0.98073748, 0.35227656]],
#
#        [[1.218166  , 1.25045213, 1.23911828, 1.23192083, 0.07503997],
#         [1.22417745, 1.25825053, 1.24757882, 1.23676401, 0.0736978 ],
#         [1.24549139, 1.25655513, 1.25325615, 1.24413878, 0.06965041],
#         ...,
#         [1.05312057, 1.06385635, 1.01591888, 1.00209139, 0.39458716],
#         [0.97256537, 1.03367988, 0.98986971, 0.98073748, 0.35227656],
#         [0.9973767 , 1.00316454, 0.92842026, 0.92096871, 0.49075258]],
#
#        ...,
#
#        [[1.32440713, 1.36437621, 1.34709999, 1.3408916 , 0.18610554],
#         [1.33500923, 1.35759495, 1.35244354, 1.34958735, 0.11395486],
#         [1.36954857, 1.39805609, 1.37838144, 1.3663181 , 0.12063485],
#         ...,
#         [0.6924254 , 0.69767178, 0.62963371, 0.63577329, 0.37381093],
#         [0.63121646, 0.63731919, 0.58744298, 0.59108427, 0.53027139],
#         [0.59252378, 0.59267637, 0.52432378, 0.52394055, 0.83841861]],
#
#        [[1.33500923, 1.35759495, 1.35244354, 1.34958735, 0.11395486],
#         [1.36954857, 1.39805609, 1.37838144, 1.3663181 , 0.12063485],
#         [1.36189749, 1.40461127, 1.38149843, 1.3885526 , 0.1324487 ],
#         ...,
#         [0.63121646, 0.63731919, 0.58744298, 0.59108427, 0.53027139],
#         [0.59252378, 0.59267637, 0.52432378, 0.52394055, 0.83841861],
#         [0.49732204, 0.51797021, 0.49048198, 0.48101272, 0.25563158]],
#
#        [[1.36954857, 1.39805609, 1.37838144, 1.3663181 , 0.12063485],
#         [1.36189749, 1.40461127, 1.38149843, 1.3885526 , 0.1324487 ],
#         [1.39250196, 1.44382918, 1.41656459, 1.41926266, 0.17091885],
#         ...,
#         [0.59252378, 0.59267637, 0.52432378, 0.52394055, 0.83841861],
#         [0.49732204, 0.51797021, 0.49048198, 0.48101272, 0.25563158],
#         [0.49896166, 0.58216543, 0.49192922, 0.59482666, 0.46867995]]])

# %%
# try with real testing data


y_pred = lstm_model.predict(createDataset(x_test_t, batchSize), batch_size=batchSize)
y_pred = y_pred.flatten()
y_test_t = createDataset(y_test_t, batchSize)
error = mean_squared_error(y_test_t, y_pred)
print("Error is", error, y_pred.shape, y_test_t.shape)
print(y_pred[0:15])
print(y_test_t[0:15])
y_pred_org = (y_pred * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3] # min_max_scaler.inverse_transform(y_pred)
y_test_t_org = (y_test_t * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3] # min_max_scaler.inverse_transform(y_test_t)
print(y_pred_org[0:15])
print(y_test_t_org[0:15])
# Out:
# Error is 0.16404551011604268 (20,) (20,)
# [0.654813   0.6237168  0.5909096  0.562724   0.5425863  0.5182418
#  0.47834212 0.44984236 0.42320192 0.39423916 0.3697394  0.35609007
#  0.3485892  0.34281301 0.34486264]
# [0.98073748 0.92096871 0.9717117  0.99504681 0.91062196 0.81287837
#  0.81067697 0.76125478 0.78690148 0.78271887 0.85646677 0.84116684
#  0.83048988 0.89917459 0.80968637]
# [162.61975 159.79466 156.81413 154.25348 152.42397 150.21227 146.58737
#  143.99817 141.5779  138.94662 136.72083 135.48077 134.79933 134.27457
#  134.46077]
# [192.22999573 186.80000305 191.41000366 193.52999878 185.86000061
#  176.97999573 176.77999878 172.28999329 174.61999512 174.24000549
#  180.94000244 179.55000305 178.58000183 184.82000732 176.69000244]

# %%
# is_update_model = True
# if model is None or is_update_model:
#     from keras import backend as K
#     print("Building model...")
#     print("checking if GPU available", K.tensorflow_backend._get_available_gpus())
#     model = create_model()
    
#     es = EarlyStopping(monitor='val_loss', mode='min', verbose=1,
#                        patience=40, min_delta=0.0001)
    
#     mcp = ModelCheckpoint(os.path.join(OUTPUT_PATH,
#                           "best_model.h5"), monitor='val_loss', verbose=1,
#                           save_best_only=True, save_weights_only=False, mode='min', period=1)

#     # Not used here. But leaving it here as a reminder for future
#     r_lr_plat = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=30, 
#                                   verbose=0, mode='auto', min_delta=0.0001, cooldown=0, min_lr=0)
    
#     csv_logger = CSVLogger(os.path.join(OUTPUT_PATH, 'training_log_' + time.ctime().replace(" ","_") + '.log'), append=True)
    
#     history = model.fit(x_t, y_t, epochs=params["epochs"], verbose=2, batch_size=batchSize,
#                         shuffle=False, validation_data=(createDataset(x_val, batchSize),
#                         createDataset(y_val, batchSize)), callbacks=[es, mcp, csv_logger])
    
#     print("saving model...")
#     pickle.dump(model, open("lstm_model", "wb"))

# # model.evaluate(x_test_t, y_test_t, batch_size=batchSize
# y_pred = model.predict(createDataset(x_test_t, batchSize), batch_size=batchSize)
# y_pred = y_pred.flatten()
# y_test_t = createDataset(y_test_t, batchSize)
# error = mean_squared_error(y_test_t, y_pred)
# print("Error is", error, y_pred.shape, y_test_t.shape)
# print(y_pred[0:15])
# print(y_test_t[0:15])

# # convert the predicted value to range of real data
# y_pred_org = (y_pred * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3]
# # min_max_scaler.inverse_transform(y_pred)
# y_test_t_org = (y_test_t * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3]
# # min_max_scaler.inverse_transform(y_test_t)
# print(y_pred_org[0:15])
# print(y_test_t_org[0:15])

# # Visualize the training data
# from matplotlib import pyplot as plt
# plt.figure()
# plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
# plt.title('Model loss')
# plt.ylabel('Loss')
# plt.xlabel('Epoch')
# plt.legend(['Train', 'Test'], loc='upper left')
# #plt.show()
# plt.savefig(os.path.join(OUTPUT_PATH, 'train_vis_BS_'+str(batchSize)+"_"+time.ctime()+'.png'))

# # load the saved best model from above
# saved_model = load_model(os.path.join(OUTPUT_PATH, 'best_model.h5')) # , "lstm_best_7-3-19_12AM",
# print(saved_model)

# y_pred = saved_model.predict(createDataset(x_test_t, batchSize), batch_size=batchSize)
# y_pred = y_pred.flatten()
# y_test_t = createDataset(y_test_t, batchSize)
# error = mean_squared_error(y_test_t, y_pred)
# print("Error is", error, y_pred.shape, y_test_t.shape)
# print(y_pred[0:15])
# print(y_test_t[0:15])
# y_pred_org = (y_pred * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3] # min_max_scaler.inverse_transform(y_pred)
# y_test_t_org = (y_test_t * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3] # min_max_scaler.inverse_transform(y_test_t)
# print(y_pred_org[0:15])
# print(y_test_t_org[0:15])

# # Visualize the prediction
# from matplotlib import pyplot as plt
# plt.figure()
# plt.plot(y_pred_org)
# plt.plot(y_test_t_org)
# plt.title('Prediction vs Real Stock Price')
# plt.ylabel('Price')
# plt.xlabel('Days')
# plt.legend(['Prediction', 'Real'], loc='upper left')
# #plt.show()
# plt.savefig(os.path.join(OUTPUT_PATH, 'pred_vs_real_BS'+str(batchSize)+"_"+time.ctime()+'.png'))
# print_time("program completed ", stime)
