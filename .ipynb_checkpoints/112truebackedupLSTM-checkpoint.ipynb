# %%
# Author: Roshan Ram
# AndrewID: rram

import yfinance as yfinance

# import module_manager
# module_manager.review()

import yfinance as yf # to pull stock data with yf.download(name, yyyy-mm-dd of opening, yyyy-mm-dd of opening)

import numpy as np # used for everything lol
import pandas as pd # data mainpulation
import matplotlib.pyplot as plt # graphing/plotting
from keras import *

import time, random, copy

#####
import numpy as np
import os
import sys
import time
import pandas as pd 
# from tqdm._tqdm_notebook import tqdm_notebook
import pickle
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout
from keras.layers import LSTM
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger
from keras import optimizers
# from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import logging
####

# %matplotlib inline 
#just to make stuff look nice

# %%
stock = None
while not isinstance(stock, str):
    stock = input("Enter your desired stock. Only alphanumeric characters please.")
openingInp = input("Enter your desired opening date. (yyyy-mm-dd)") #'2016-01-01'
closingInp = input("Enter your desired closing date. (yyyy-mm-dd)") # '2019-08-01'


data = yf.download(stock, openingInp, closingInp)


def getData(app):
    stock = None
#     while not isinstance(stock, str):
    stock = app.getUserInput("Enter your desired stock. Only alphanumeric characters please.")
    openingInp = app.getUserInput("Enter your desired opening date. (yyyy-mm-dd)") #'2016-01-01'
    closingInp = app.getUserInput("Enter your desired closing date. (yyyy-mm-dd)") # '2019-08-01'


    data = yf.download(stock, openingInp, closingInp)
    return data, stock 

# data, stock = getData(app)
# Out:
# Enter your desired stock. Only alphanumeric characters please.AAPL
# Enter your desired opening date. (yyyy-mm-dd)2016-08-01
# Enter your desired closing date. (yyyy-mm-dd)2019-01-01
# [*********************100%***********************]  1 of 1 completed

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# def mainFunc():

TIME_STEPS = 12 # [rram] 
batchSize = 32 # [rram]


#####
params = {
    "batch_size": 20,  # 20<16<10, 25 was a bust
    "epochs": 300,
    "lr": 0.00010000,
    "time_steps": 60
}

iter_changes = "dropout_layers_0.4_0.4"

# INPUT_PATH = PATH_TO_DRIVE_ML_DATA+"/inputs"
OUTPUT_PATH = '~/Desktop'
TIME_STEPS = params["time_steps"]
batchSize = params["batch_size"]
stime = time.time()
###


train_cols = ["Open","High","Low","Close","Volume"]
df_train, df_test = train_test_split(data, train_size=0.8, test_size=0.2, shuffle=False)
print("Train and Test size", len(df_train), len(df_test))
# scale the feature MinMax, build array
x = df_train.loc[:,train_cols].values
min_max_scaler = MinMaxScaler()
x_train = min_max_scaler.fit_transform(x)
x_test = min_max_scaler.transform(df_test.loc[:,train_cols])

print((x_train.shape))
print((x_test.shape))
# Out:
# Train and Test size 487 122
# (487, 5)
# 122

# %%
def createTimesteps(mat, y_col_index):
    # y_col_index is the index of column that would act as output column
    # total number of time-series samples would be len(mat) - TIME_STEPS
    dim_0 = mat.shape[0] - TIME_STEPS
    dim_1 = mat.shape[1]
    x = np.zeros((dim_0, TIME_STEPS, dim_1))
    y = np.zeros((dim_0,))

    for i in (range(dim_0)):
        x[i] = mat[i:TIME_STEPS+i]
        y[i] = mat[TIME_STEPS+i, y_col_index]
    print("length of time-series i/o",x.shape,y.shape)
    return x, y

def createDataset(mat, batch_size):
    """
    trims dataset to a size that's divisible by batchSize
    """
    no_of_rows_drop = mat.shape[0]%batch_size
    if(no_of_rows_drop > 0):
        return mat[:-no_of_rows_drop]
    else:
        return mat

# %%
x_t, y_t = createTimesteps(x_train, 3)
x_t = createDataset(x_t, batchSize)
y_t = createDataset(y_t, batchSize)
x_temp, y_temp = createTimesteps(x_test, 3)
x_val, x_test_t = np.split(createDataset(x_temp, batchSize),2)
y_val, y_test_t = np.split(createDataset(y_temp, batchSize),2)
# Out:
# length of time-series i/o (427, 60, 5) (427,)
# length of time-series i/o (62, 60, 5) (62,)

# %%
# def create_model():
lstm_model = Sequential()
lstm_model.add(LSTM(100, batch_input_shape=(batchSize, TIME_STEPS, x_t.shape[2]), dropout=0.0, recurrent_dropout=0.0, stateful=True,     kernel_initializer='random_uniform'))
lstm_model.add(Dropout(0.5))
lstm_model.add(Dense(20,activation='relu'))
lstm_model.add(Dense(1,activation='sigmoid'))
optimizer = optimizers.RMSprop(lr=0.00010000)
lstm_model.compile(loss='mean_squared_error', optimizer=optimizer)

# %%
model = lstm_model

# %%
csv_logger = CSVLogger(os.path.join(OUTPUT_PATH, 'your_log_name' + '.log'), append=True)

# epochs = params['epochs']


# NOTE TO SELF CHANGE EPOCHS BACK to 300
history = model.fit(x_t, y_t, epochs=300, verbose=2, batch_size=batchSize,
                    shuffle=False, validation_data=(createDataset(x_val, batchSize),
                    createDataset(y_val, batchSize))) #callbacks=[csv_logger])

# history = model.fit(x_t, y_t, epochs=params["epochs"], verbose=2, batch_size=batchSize,
#                         shuffle=False, validation_data=(createDataset(x_val, batchSize),
#                         createDataset(y_val, batchSize)), callbacks=[es, mcp, csv_logger])
# Out:
# Train on 420 samples, validate on 20 samples
# Epoch 1/300
#  - 1s - loss: 0.0616 - val_loss: 0.5580
# Epoch 2/300
#  - 1s - loss: 0.0553 - val_loss: 0.4836
# Epoch 3/300
#  - 1s - loss: 0.0507 - val_loss: 0.4034
# Epoch 4/300
#  - 1s - loss: 0.0463 - val_loss: 0.3208
# Epoch 5/300
#  - 1s - loss: 0.0416 - val_loss: 0.2482
# Epoch 6/300
#  - 1s - loss: 0.0403 - val_loss: 0.2081
# Epoch 7/300
#  - 1s - loss: 0.0388 - val_loss: 0.1856
# Epoch 8/300
#  - 1s - loss: 0.0381 - val_loss: 0.1773
# Epoch 9/300
#  - 1s - loss: 0.0365 - val_loss: 0.1651
# Epoch 10/300
#  - 1s - loss: 0.0357 - val_loss: 0.1577
# Epoch 11/300
#  - 1s - loss: 0.0337 - val_loss: 0.1517
# Epoch 12/300
#  - 1s - loss: 0.0323 - val_loss: 0.1465
# Epoch 13/300
#  - 1s - loss: 0.0314 - val_loss: 0.1423
# Epoch 14/300
#  - 1s - loss: 0.0305 - val_loss: 0.1416
# Epoch 15/300
#  - 1s - loss: 0.0290 - val_loss: 0.1409
# Epoch 16/300
#  - 1s - loss: 0.0279 - val_loss: 0.1383
# Epoch 17/300
#  - 1s - loss: 0.0280 - val_loss: 0.1374
# Epoch 18/300
#  - 1s - loss: 0.0265 - val_loss: 0.1364
# Epoch 19/300
#  - 1s - loss: 0.0247 - val_loss: 0.1361
# Epoch 20/300
#  - 1s - loss: 0.0234 - val_loss: 0.1355
# Epoch 21/300
#  - 1s - loss: 0.0220 - val_loss: 0.1372
# Epoch 22/300
#  - 1s - loss: 0.0209 - val_loss: 0.1376
# Epoch 23/300
#  - 1s - loss: 0.0192 - val_loss: 0.1381
# Epoch 24/300
#  - 1s - loss: 0.0176 - val_loss: 0.1396
# Epoch 25/300
#  - 1s - loss: 0.0165 - val_loss: 0.1385
# Epoch 26/300
#  - 1s - loss: 0.0156 - val_loss: 0.1402
# Epoch 27/300
#  - 1s - loss: 0.0145 - val_loss: 0.1404
# Epoch 28/300
#  - 1s - loss: 0.0137 - val_loss: 0.1386
# Epoch 29/300
#  - 1s - loss: 0.0129 - val_loss: 0.1405
# Epoch 30/300
#  - 1s - loss: 0.0125 - val_loss: 0.1373
# Epoch 31/300
#  - 1s - loss: 0.0124 - val_loss: 0.1370
# Epoch 32/300
#  - 1s - loss: 0.0117 - val_loss: 0.1366
# Epoch 33/300
#  - 1s - loss: 0.0111 - val_loss: 0.1346
# Epoch 34/300
#  - 1s - loss: 0.0106 - val_loss: 0.1343
# Epoch 35/300
#  - 1s - loss: 0.0107 - val_loss: 0.1337
# Epoch 36/300
#  - 1s - loss: 0.0098 - val_loss: 0.1311
# Epoch 37/300
#  - 1s - loss: 0.0097 - val_loss: 0.1308
# Epoch 38/300
#  - 1s - loss: 0.0099 - val_loss: 0.1298
# Epoch 39/300
#  - 1s - loss: 0.0089 - val_loss: 0.1281
# Epoch 40/300
#  - 1s - loss: 0.0089 - val_loss: 0.1280
# Epoch 41/300
#  - 1s - loss: 0.0089 - val_loss: 0.1266
# Epoch 42/300
#  - 1s - loss: 0.0081 - val_loss: 0.1256
# Epoch 43/300
#  - 1s - loss: 0.0085 - val_loss: 0.1240
# Epoch 44/300
#  - 1s - loss: 0.0087 - val_loss: 0.1238
# Epoch 45/300
#  - 1s - loss: 0.0083 - val_loss: 0.1234
# Epoch 46/300
#  - 1s - loss: 0.0083 - val_loss: 0.1221
# Epoch 47/300
#  - 1s - loss: 0.0083 - val_loss: 0.1220
# Epoch 48/300
#  - 1s - loss: 0.0082 - val_loss: 0.1215
# Epoch 49/300
#  - 1s - loss: 0.0077 - val_loss: 0.1215
# Epoch 50/300
#  - 1s - loss: 0.0075 - val_loss: 0.1204
# Epoch 51/300
#  - 1s - loss: 0.0076 - val_loss: 0.1200
# Epoch 52/300
#  - 1s - loss: 0.0078 - val_loss: 0.1196
# Epoch 53/300
#  - 1s - loss: 0.0069 - val_loss: 0.1189
# Epoch 54/300
#  - 1s - loss: 0.0070 - val_loss: 0.1194
# Epoch 55/300
#  - 1s - loss: 0.0071 - val_loss: 0.1186
# Epoch 56/300
#  - 1s - loss: 0.0068 - val_loss: 0.1191
# Epoch 57/300
#  - 1s - loss: 0.0072 - val_loss: 0.1180
# Epoch 58/300
#  - 1s - loss: 0.0067 - val_loss: 0.1179
# Epoch 59/300
#  - 1s - loss: 0.0070 - val_loss: 0.1184
# Epoch 60/300
#  - 1s - loss: 0.0070 - val_loss: 0.1182
# Epoch 61/300
#  - 1s - loss: 0.0073 - val_loss: 0.1190
# Epoch 62/300
#  - 1s - loss: 0.0067 - val_loss: 0.1191
# Epoch 63/300
#  - 1s - loss: 0.0068 - val_loss: 0.1191
# Epoch 64/300
#  - 1s - loss: 0.0071 - val_loss: 0.1180
# Epoch 65/300
#  - 1s - loss: 0.0064 - val_loss: 0.1192
# Epoch 66/300
#  - 1s - loss: 0.0062 - val_loss: 0.1182
# Epoch 67/300
#  - 1s - loss: 0.0062 - val_loss: 0.1187
# Epoch 68/300
#  - 1s - loss: 0.0063 - val_loss: 0.1190
# Epoch 69/300
#  - 1s - loss: 0.0063 - val_loss: 0.1189
# Epoch 70/300
#  - 1s - loss: 0.0062 - val_loss: 0.1190
# Epoch 71/300
#  - 1s - loss: 0.0068 - val_loss: 0.1190
# Epoch 72/300
#  - 1s - loss: 0.0057 - val_loss: 0.1194
# Epoch 73/300
#  - 1s - loss: 0.0063 - val_loss: 0.1195
# Epoch 74/300
#  - 1s - loss: 0.0064 - val_loss: 0.1195
# Epoch 75/300
#  - 1s - loss: 0.0061 - val_loss: 0.1193
# Epoch 76/300
#  - 1s - loss: 0.0061 - val_loss: 0.1197
# Epoch 77/300
#  - 1s - loss: 0.0059 - val_loss: 0.1198
# Epoch 78/300
#  - 1s - loss: 0.0056 - val_loss: 0.1195
# Epoch 79/300
#  - 1s - loss: 0.0062 - val_loss: 0.1202
# Epoch 80/300
#  - 1s - loss: 0.0059 - val_loss: 0.1214
# Epoch 81/300
#  - 1s - loss: 0.0060 - val_loss: 0.1208
# Epoch 82/300
#  - 1s - loss: 0.0059 - val_loss: 0.1210
# Epoch 83/300
#  - 1s - loss: 0.0056 - val_loss: 0.1197
# Epoch 84/300
#  - 1s - loss: 0.0055 - val_loss: 0.1202
# Epoch 85/300
#  - 1s - loss: 0.0058 - val_loss: 0.1200
# Epoch 86/300
#  - 1s - loss: 0.0062 - val_loss: 0.1201
# Epoch 87/300
#  - 1s - loss: 0.0057 - val_loss: 0.1203
# Epoch 88/300
#  - 1s - loss: 0.0056 - val_loss: 0.1203
# Epoch 89/300
#  - 1s - loss: 0.0055 - val_loss: 0.1208
# Epoch 90/300
#  - 1s - loss: 0.0058 - val_loss: 0.1211
# Epoch 91/300
#  - 1s - loss: 0.0054 - val_loss: 0.1216
# Epoch 92/300
#  - 1s - loss: 0.0051 - val_loss: 0.1219
# Epoch 93/300
#  - 1s - loss: 0.0054 - val_loss: 0.1211
# Epoch 94/300
#  - 1s - loss: 0.0060 - val_loss: 0.1218
# Epoch 95/300
#  - 1s - loss: 0.0056 - val_loss: 0.1226
# Epoch 96/300
#  - 1s - loss: 0.0056 - val_loss: 0.1226
# Epoch 97/300
#  - 1s - loss: 0.0051 - val_loss: 0.1226
# Epoch 98/300
#  - 1s - loss: 0.0055 - val_loss: 0.1233
# Epoch 99/300
#  - 1s - loss: 0.0058 - val_loss: 0.1235
# Epoch 100/300
#  - 1s - loss: 0.0049 - val_loss: 0.1219
# Epoch 101/300
#  - 1s - loss: 0.0054 - val_loss: 0.1235
# Epoch 102/300
#  - 1s - loss: 0.0053 - val_loss: 0.1224
# Epoch 103/300
#  - 1s - loss: 0.0053 - val_loss: 0.1233
# Epoch 104/300
#  - 1s - loss: 0.0053 - val_loss: 0.1239
# Epoch 105/300
#  - 1s - loss: 0.0051 - val_loss: 0.1239
# Epoch 106/300
#  - 1s - loss: 0.0053 - val_loss: 0.1237
# Epoch 107/300
#  - 1s - loss: 0.0054 - val_loss: 0.1239
# Epoch 108/300
#  - 1s - loss: 0.0054 - val_loss: 0.1231
# Epoch 109/300
#  - 1s - loss: 0.0051 - val_loss: 0.1240
# Epoch 110/300
#  - 1s - loss: 0.0054 - val_loss: 0.1237
# Epoch 111/300
#  - 1s - loss: 0.0055 - val_loss: 0.1233
# Epoch 112/300
#  - 1s - loss: 0.0052 - val_loss: 0.1227
# Epoch 113/300
#  - 1s - loss: 0.0057 - val_loss: 0.1232
# Epoch 114/300
#  - 1s - loss: 0.0053 - val_loss: 0.1231
# Epoch 115/300
#  - 1s - loss: 0.0053 - val_loss: 0.1234
# Epoch 116/300
#  - 1s - loss: 0.0052 - val_loss: 0.1236
# Epoch 117/300
#  - 1s - loss: 0.0053 - val_loss: 0.1253
# Epoch 118/300
#  - 1s - loss: 0.0048 - val_loss: 0.1242
# Epoch 119/300
#  - 1s - loss: 0.0051 - val_loss: 0.1238
# Epoch 120/300
#  - 1s - loss: 0.0054 - val_loss: 0.1245
# Epoch 121/300
#  - 1s - loss: 0.0049 - val_loss: 0.1234
# Epoch 122/300
#  - 1s - loss: 0.0052 - val_loss: 0.1232
# Epoch 123/300
#  - 1s - loss: 0.0049 - val_loss: 0.1240
# Epoch 124/300
#  - 1s - loss: 0.0050 - val_loss: 0.1224
# Epoch 125/300
#  - 1s - loss: 0.0052 - val_loss: 0.1235
# Epoch 126/300
#  - 1s - loss: 0.0049 - val_loss: 0.1234
# Epoch 127/300
#  - 1s - loss: 0.0052 - val_loss: 0.1224
# Epoch 128/300
#  - 1s - loss: 0.0053 - val_loss: 0.1230
# Epoch 129/300
#  - 1s - loss: 0.0048 - val_loss: 0.1227
# Epoch 130/300
#  - 1s - loss: 0.0050 - val_loss: 0.1227
# Epoch 131/300
#  - 1s - loss: 0.0050 - val_loss: 0.1231
# Epoch 132/300
#  - 1s - loss: 0.0054 - val_loss: 0.1233
# Epoch 133/300
#  - 1s - loss: 0.0052 - val_loss: 0.1230
# Epoch 134/300
#  - 1s - loss: 0.0049 - val_loss: 0.1217
# Epoch 135/300
#  - 1s - loss: 0.0051 - val_loss: 0.1233
# Epoch 136/300
#  - 1s - loss: 0.0051 - val_loss: 0.1229
# Epoch 137/300
#  - 1s - loss: 0.0042 - val_loss: 0.1222
# Epoch 138/300
#  - 1s - loss: 0.0047 - val_loss: 0.1215
# Epoch 139/300
#  - 1s - loss: 0.0049 - val_loss: 0.1215
# Epoch 140/300
#  - 1s - loss: 0.0048 - val_loss: 0.1219
# Epoch 141/300
#  - 1s - loss: 0.0047 - val_loss: 0.1224
# Epoch 142/300
#  - 1s - loss: 0.0047 - val_loss: 0.1215
# Epoch 143/300
#  - 1s - loss: 0.0047 - val_loss: 0.1208
# Epoch 144/300
#  - 1s - loss: 0.0049 - val_loss: 0.1208
# Epoch 145/300
#  - 1s - loss: 0.0050 - val_loss: 0.1219
# Epoch 146/300
#  - 1s - loss: 0.0048 - val_loss: 0.1207
# Epoch 147/300
#  - 1s - loss: 0.0049 - val_loss: 0.1211
# Epoch 148/300
#  - 1s - loss: 0.0051 - val_loss: 0.1209
# Epoch 149/300
#  - 1s - loss: 0.0048 - val_loss: 0.1200
# Epoch 150/300
#  - 1s - loss: 0.0049 - val_loss: 0.1198
# Epoch 151/300
#  - 1s - loss: 0.0048 - val_loss: 0.1195
# Epoch 152/300
#  - 1s - loss: 0.0053 - val_loss: 0.1191
# Epoch 153/300
#  - 1s - loss: 0.0047 - val_loss: 0.1194
# Epoch 154/300
#  - 1s - loss: 0.0047 - val_loss: 0.1189
# Epoch 155/300
#  - 1s - loss: 0.0048 - val_loss: 0.1194
# Epoch 156/300
#  - 1s - loss: 0.0050 - val_loss: 0.1197
# Epoch 157/300
#  - 1s - loss: 0.0045 - val_loss: 0.1195
# Epoch 158/300
#  - 1s - loss: 0.0045 - val_loss: 0.1187
# Epoch 159/300
#  - 1s - loss: 0.0048 - val_loss: 0.1195
# Epoch 160/300
#  - 1s - loss: 0.0048 - val_loss: 0.1190
# Epoch 161/300
#  - 1s - loss: 0.0048 - val_loss: 0.1182
# Epoch 162/300
#  - 1s - loss: 0.0045 - val_loss: 0.1181
# Epoch 163/300
#  - 1s - loss: 0.0047 - val_loss: 0.1183
# Epoch 164/300
#  - 1s - loss: 0.0046 - val_loss: 0.1178
# Epoch 165/300
#  - 1s - loss: 0.0045 - val_loss: 0.1169
# Epoch 166/300
#  - 1s - loss: 0.0047 - val_loss: 0.1166
# Epoch 167/300
#  - 1s - loss: 0.0046 - val_loss: 0.1172
# Epoch 168/300
#  - 1s - loss: 0.0043 - val_loss: 0.1160
# Epoch 169/300
#  - 1s - loss: 0.0046 - val_loss: 0.1162
# Epoch 170/300
#  - 1s - loss: 0.0048 - val_loss: 0.1174
# Epoch 171/300
#  - 1s - loss: 0.0043 - val_loss: 0.1172
# Epoch 172/300
#  - 1s - loss: 0.0044 - val_loss: 0.1166
# Epoch 173/300
#  - 1s - loss: 0.0044 - val_loss: 0.1166
# Epoch 174/300
#  - 1s - loss: 0.0044 - val_loss: 0.1163
# Epoch 175/300
#  - 1s - loss: 0.0044 - val_loss: 0.1150
# Epoch 176/300
#  - 1s - loss: 0.0047 - val_loss: 0.1170
# Epoch 177/300
#  - 1s - loss: 0.0043 - val_loss: 0.1160
# Epoch 178/300
#  - 1s - loss: 0.0043 - val_loss: 0.1144
# Epoch 179/300
#  - 1s - loss: 0.0046 - val_loss: 0.1149
# Epoch 180/300
#  - 1s - loss: 0.0043 - val_loss: 0.1154
# Epoch 181/300
#  - 1s - loss: 0.0043 - val_loss: 0.1149
# Epoch 182/300
#  - 1s - loss: 0.0046 - val_loss: 0.1152
# Epoch 183/300
#  - 1s - loss: 0.0044 - val_loss: 0.1148
# Epoch 184/300
#  - 1s - loss: 0.0045 - val_loss: 0.1152
# Epoch 185/300
#  - 1s - loss: 0.0046 - val_loss: 0.1144
# Epoch 186/300
#  - 1s - loss: 0.0041 - val_loss: 0.1142
# Epoch 187/300
#  - 1s - loss: 0.0040 - val_loss: 0.1143
# Epoch 188/300
#  - 1s - loss: 0.0044 - val_loss: 0.1144
# Epoch 189/300
#  - 1s - loss: 0.0045 - val_loss: 0.1134
# Epoch 190/300
#  - 1s - loss: 0.0044 - val_loss: 0.1136
# Epoch 191/300
#  - 1s - loss: 0.0043 - val_loss: 0.1136
# Epoch 192/300
#  - 1s - loss: 0.0044 - val_loss: 0.1140
# Epoch 193/300
#  - 1s - loss: 0.0044 - val_loss: 0.1133
# Epoch 194/300
#  - 1s - loss: 0.0043 - val_loss: 0.1121
# Epoch 195/300
#  - 1s - loss: 0.0045 - val_loss: 0.1127
# Epoch 196/300
#  - 1s - loss: 0.0040 - val_loss: 0.1123
# Epoch 197/300
#  - 1s - loss: 0.0039 - val_loss: 0.1115
# Epoch 198/300
#  - 1s - loss: 0.0043 - val_loss: 0.1121
# Epoch 199/300
#  - 1s - loss: 0.0043 - val_loss: 0.1118
# Epoch 200/300
#  - 1s - loss: 0.0043 - val_loss: 0.1118
# Epoch 201/300
#  - 1s - loss: 0.0043 - val_loss: 0.1118
# Epoch 202/300
#  - 1s - loss: 0.0041 - val_loss: 0.1118
# Epoch 203/300
#  - 1s - loss: 0.0044 - val_loss: 0.1121
# Epoch 204/300
#  - 1s - loss: 0.0039 - val_loss: 0.1120
# Epoch 205/300
#  - 1s - loss: 0.0047 - val_loss: 0.1116
# Epoch 206/300
#  - 1s - loss: 0.0041 - val_loss: 0.1109
# Epoch 207/300
#  - 1s - loss: 0.0044 - val_loss: 0.1112
# Epoch 208/300
#  - 1s - loss: 0.0041 - val_loss: 0.1120
# Epoch 209/300
#  - 1s - loss: 0.0040 - val_loss: 0.1122
# Epoch 210/300
#  - 1s - loss: 0.0043 - val_loss: 0.1118
# Epoch 211/300
#  - 1s - loss: 0.0039 - val_loss: 0.1107
# Epoch 212/300
#  - 1s - loss: 0.0042 - val_loss: 0.1112
# Epoch 213/300
#  - 1s - loss: 0.0045 - val_loss: 0.1122
# Epoch 214/300
#  - 1s - loss: 0.0041 - val_loss: 0.1120
# Epoch 215/300
#  - 1s - loss: 0.0039 - val_loss: 0.1120
# Epoch 216/300
#  - 1s - loss: 0.0043 - val_loss: 0.1124
# Epoch 217/300
#  - 1s - loss: 0.0037 - val_loss: 0.1106
# Epoch 218/300
#  - 1s - loss: 0.0036 - val_loss: 0.1101
# Epoch 219/300
#  - 1s - loss: 0.0038 - val_loss: 0.1109
# Epoch 220/300
#  - 1s - loss: 0.0038 - val_loss: 0.1112
# Epoch 221/300
#  - 1s - loss: 0.0039 - val_loss: 0.1112
# Epoch 222/300
#  - 1s - loss: 0.0040 - val_loss: 0.1115
# Epoch 223/300
#  - 1s - loss: 0.0038 - val_loss: 0.1119
# Epoch 224/300
#  - 1s - loss: 0.0041 - val_loss: 0.1123
# Epoch 225/300
#  - 1s - loss: 0.0043 - val_loss: 0.1129
# Epoch 226/300
#  - 1s - loss: 0.0036 - val_loss: 0.1118
# Epoch 227/300
#  - 1s - loss: 0.0040 - val_loss: 0.1126
# Epoch 228/300
#  - 1s - loss: 0.0037 - val_loss: 0.1122
# Epoch 229/300
#  - 1s - loss: 0.0036 - val_loss: 0.1124
# Epoch 230/300
#  - 1s - loss: 0.0040 - val_loss: 0.1118
# Epoch 231/300
#  - 1s - loss: 0.0036 - val_loss: 0.1112
# Epoch 232/300
#  - 1s - loss: 0.0040 - val_loss: 0.1116
# Epoch 233/300
#  - 1s - loss: 0.0037 - val_loss: 0.1112
# Epoch 234/300
#  - 1s - loss: 0.0035 - val_loss: 0.1108
# Epoch 235/300
#  - 1s - loss: 0.0036 - val_loss: 0.1127
# Epoch 236/300
#  - 1s - loss: 0.0037 - val_loss: 0.1122
# Epoch 237/300
#  - 1s - loss: 0.0039 - val_loss: 0.1124
# Epoch 238/300
#  - 1s - loss: 0.0036 - val_loss: 0.1135
# Epoch 239/300
#  - 1s - loss: 0.0034 - val_loss: 0.1125
# Epoch 240/300
#  - 1s - loss: 0.0034 - val_loss: 0.1120
# Epoch 241/300
#  - 1s - loss: 0.0038 - val_loss: 0.1132
# Epoch 242/300
#  - 1s - loss: 0.0036 - val_loss: 0.1134
# Epoch 243/300
#  - 1s - loss: 0.0037 - val_loss: 0.1141
# Epoch 244/300
#  - 1s - loss: 0.0038 - val_loss: 0.1152
# Epoch 245/300
#  - 1s - loss: 0.0036 - val_loss: 0.1138
# Epoch 246/300
#  - 1s - loss: 0.0036 - val_loss: 0.1145
# Epoch 247/300
#  - 1s - loss: 0.0035 - val_loss: 0.1141
# Epoch 248/300
#  - 1s - loss: 0.0038 - val_loss: 0.1148
# Epoch 249/300
#  - 1s - loss: 0.0036 - val_loss: 0.1144
# Epoch 250/300
#  - 1s - loss: 0.0038 - val_loss: 0.1142
# Epoch 251/300
#  - 1s - loss: 0.0037 - val_loss: 0.1143
# Epoch 252/300
#  - 1s - loss: 0.0034 - val_loss: 0.1147
# Epoch 253/300
#  - 1s - loss: 0.0036 - val_loss: 0.1143
# Epoch 254/300
#  - 1s - loss: 0.0035 - val_loss: 0.1173
# Epoch 255/300
#  - 1s - loss: 0.0033 - val_loss: 0.1166
# Epoch 256/300
#  - 1s - loss: 0.0033 - val_loss: 0.1172
# Epoch 257/300
#  - 1s - loss: 0.0033 - val_loss: 0.1165
# Epoch 258/300
#  - 1s - loss: 0.0036 - val_loss: 0.1161
# Epoch 259/300
#  - 1s - loss: 0.0034 - val_loss: 0.1175
# Epoch 260/300
#  - 1s - loss: 0.0032 - val_loss: 0.1168
# Epoch 261/300
#  - 1s - loss: 0.0037 - val_loss: 0.1157
# Epoch 262/300
#  - 1s - loss: 0.0032 - val_loss: 0.1151
# Epoch 263/300
#  - 1s - loss: 0.0036 - val_loss: 0.1150
# Epoch 264/300
#  - 1s - loss: 0.0033 - val_loss: 0.1161
# Epoch 265/300
#  - 1s - loss: 0.0034 - val_loss: 0.1154
# Epoch 266/300
#  - 1s - loss: 0.0037 - val_loss: 0.1153
# Epoch 267/300
#  - 1s - loss: 0.0031 - val_loss: 0.1151
# Epoch 268/300
#  - 1s - loss: 0.0035 - val_loss: 0.1158
# Epoch 269/300
#  - 1s - loss: 0.0030 - val_loss: 0.1167
# Epoch 270/300
#  - 1s - loss: 0.0032 - val_loss: 0.1156
# Epoch 271/300
#  - 1s - loss: 0.0032 - val_loss: 0.1150
# Epoch 272/300
#  - 1s - loss: 0.0035 - val_loss: 0.1154
# Epoch 273/300
#  - 1s - loss: 0.0031 - val_loss: 0.1165
# Epoch 274/300
#  - 1s - loss: 0.0031 - val_loss: 0.1151
# Epoch 275/300
#  - 1s - loss: 0.0036 - val_loss: 0.1149
# Epoch 276/300
#  - 1s - loss: 0.0033 - val_loss: 0.1151
# Epoch 277/300
#  - 1s - loss: 0.0031 - val_loss: 0.1144
# Epoch 278/300
#  - 1s - loss: 0.0034 - val_loss: 0.1158
# Epoch 279/300
#  - 1s - loss: 0.0032 - val_loss: 0.1148
# Epoch 280/300
#  - 1s - loss: 0.0030 - val_loss: 0.1154
# Epoch 281/300
#  - 1s - loss: 0.0034 - val_loss: 0.1133
# Epoch 282/300
#  - 1s - loss: 0.0031 - val_loss: 0.1139
# Epoch 283/300
#  - 1s - loss: 0.0032 - val_loss: 0.1137
# Epoch 284/300
#  - 1s - loss: 0.0033 - val_loss: 0.1132
# Epoch 285/300
#  - 1s - loss: 0.0033 - val_loss: 0.1128
# Epoch 286/300
#  - 1s - loss: 0.0033 - val_loss: 0.1144
# Epoch 287/300
#  - 1s - loss: 0.0031 - val_loss: 0.1143
# Epoch 288/300
#  - 1s - loss: 0.0033 - val_loss: 0.1119
# Epoch 289/300
#  - 1s - loss: 0.0032 - val_loss: 0.1142
# Epoch 290/300
#  - 1s - loss: 0.0033 - val_loss: 0.1118
# Epoch 291/300
#  - 1s - loss: 0.0031 - val_loss: 0.1140
# Epoch 292/300
#  - 1s - loss: 0.0029 - val_loss: 0.1129
# Epoch 293/300
#  - 1s - loss: 0.0034 - val_loss: 0.1142
# Epoch 294/300
#  - 1s - loss: 0.0035 - val_loss: 0.1134
# Epoch 295/300
#  - 1s - loss: 0.0028 - val_loss: 0.1114
# Epoch 296/300
#  - 1s - loss: 0.0033 - val_loss: 0.1126
# Epoch 297/300
#  - 1s - loss: 0.0029 - val_loss: 0.1115
# Epoch 298/300
#  - 1s - loss: 0.0031 - val_loss: 0.1114
# Epoch 299/300
#  - 1s - loss: 0.0030 - val_loss: 0.1092
# Epoch 300/300
#  - 1s - loss: 0.0029 - val_loss: 0.1119

# %%
# update: SAVED MODEL!!! IMPORTANT WILL SAVE TIME ON FRONTEND FOR USER [12/4/19]
fileName = 'savedLSTM.h5'
model.save(fileName)
print(f"Saved model `{fileName}` to disk")
#######################################################################################################


y_pred = model.predict(createDataset(x_test_t, batchSize), batch_size=batchSize)
y_pred = y_pred.flatten()
y_test_t = createDataset(y_test_t, batchSize)
error = mean_squared_error(y_test_t, y_pred)
print("Error is", error, y_pred.shape, y_test_t.shape)
print(y_pred[0:15])
print(y_test_t[0:15])

# convert the predicted value to range of real data
y_pred_org = (y_pred * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3]
# min_max_scaler.inverse_transform(y_pred)
y_test_t_org = (y_test_t * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3]
# min_max_scaler.inverse_transform(y_test_t)
print(y_pred_org[0:15])
print(y_test_t_org[0:15])


# def plotLoss():
# Visualize the training data
from matplotlib import pyplot as plt
plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
#plt.show()
# Out:
# Saved model `savedLSTM.h5` to disk
# Error is 0.05590330397831712 (20,) (20,)
# [0.8868911  0.8761483  0.86230445 0.84942234 0.83914316 0.8244394
#  0.7964772  0.76938266 0.7352103  0.69264054 0.6457073  0.5965316
#  0.5547031  0.5153472  0.48501766]
# [0.98073748 0.92096871 0.9717117  0.99504681 0.91062196 0.81287837
#  0.81067697 0.76125478 0.78690148 0.78271887 0.85646677 0.84116684
#  0.83048988 0.89917459 0.80968637]
# [183.70406 182.72806 181.47035 180.30002 179.36615 178.03032 175.48996
#  173.02841 169.92386 166.0564  161.79251 157.32489 153.52478 149.94928
#  147.19385]
# [192.22999573 186.80000305 191.41000366 193.52999878 185.86000061
#  176.97999573 176.77999878 172.28999329 174.61999512 174.24000549
#  180.94000244 179.55000305 178.58000183 184.82000732 176.69000244]

# %%
x_test_t
# Out:
# array([[[1.26188662, 1.28232365, 1.25325615, 1.23643381, 0.18716514],
#         [1.24767739, 1.25983281, 1.24123342, 1.23181065, 0.14609523],
#         [1.218166  , 1.25045213, 1.23911828, 1.23192083, 0.07503997],
#         ...,
#         [1.17313364, 1.17992766, 1.16019146, 1.15971392, 0.13816361],
#         [1.12471313, 1.13347647, 1.11009684, 1.11546511, 0.22773958],
#         [1.05312057, 1.06385635, 1.01591888, 1.00209139, 0.39458716]],
#
#        [[1.24767739, 1.25983281, 1.24123342, 1.23181065, 0.14609523],
#         [1.218166  , 1.25045213, 1.23911828, 1.23192083, 0.07503997],
#         [1.22417745, 1.25825053, 1.24757882, 1.23676401, 0.0736978 ],
#         ...,
#         [1.12471313, 1.13347647, 1.11009684, 1.11546511, 0.22773958],
#         [1.05312057, 1.06385635, 1.01591888, 1.00209139, 0.39458716],
#         [0.97256537, 1.03367988, 0.98986971, 0.98073748, 0.35227656]],
#
#        [[1.218166  , 1.25045213, 1.23911828, 1.23192083, 0.07503997],
#         [1.22417745, 1.25825053, 1.24757882, 1.23676401, 0.0736978 ],
#         [1.24549139, 1.25655513, 1.25325615, 1.24413878, 0.06965041],
#         ...,
#         [1.05312057, 1.06385635, 1.01591888, 1.00209139, 0.39458716],
#         [0.97256537, 1.03367988, 0.98986971, 0.98073748, 0.35227656],
#         [0.9973767 , 1.00316454, 0.92842026, 0.92096871, 0.49075258]],
#
#        ...,
#
#        [[1.32440713, 1.36437621, 1.34709999, 1.3408916 , 0.18610554],
#         [1.33500923, 1.35759495, 1.35244354, 1.34958735, 0.11395486],
#         [1.36954857, 1.39805609, 1.37838144, 1.3663181 , 0.12063485],
#         ...,
#         [0.6924254 , 0.69767178, 0.62963371, 0.63577329, 0.37381093],
#         [0.63121646, 0.63731919, 0.58744298, 0.59108427, 0.53027139],
#         [0.59252378, 0.59267637, 0.52432378, 0.52394055, 0.83841861]],
#
#        [[1.33500923, 1.35759495, 1.35244354, 1.34958735, 0.11395486],
#         [1.36954857, 1.39805609, 1.37838144, 1.3663181 , 0.12063485],
#         [1.36189749, 1.40461127, 1.38149843, 1.3885526 , 0.1324487 ],
#         ...,
#         [0.63121646, 0.63731919, 0.58744298, 0.59108427, 0.53027139],
#         [0.59252378, 0.59267637, 0.52432378, 0.52394055, 0.83841861],
#         [0.49732204, 0.51797021, 0.49048198, 0.48101272, 0.25563158]],
#
#        [[1.36954857, 1.39805609, 1.37838144, 1.3663181 , 0.12063485],
#         [1.36189749, 1.40461127, 1.38149843, 1.3885526 , 0.1324487 ],
#         [1.39250196, 1.44382918, 1.41656459, 1.41926266, 0.17091885],
#         ...,
#         [0.59252378, 0.59267637, 0.52432378, 0.52394055, 0.83841861],
#         [0.49732204, 0.51797021, 0.49048198, 0.48101272, 0.25563158],
#         [0.49896166, 0.58216543, 0.49192922, 0.59482666, 0.46867995]]])

# %%
y_pred = lstm_model.predict(createDataset(x_test_t, batchSize), batch_size=batchSize)
y_pred = y_pred.flatten()
y_test_t = createDataset(y_test_t, batchSize)
error = mean_squared_error(y_test_t, y_pred)
print("Error is", error, y_pred.shape, y_test_t.shape)
print(y_pred[0:15])
print(y_test_t[0:15])
y_pred_org = (y_pred * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3] # min_max_scaler.inverse_transform(y_pred)
y_test_t_org = (y_test_t * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3] # min_max_scaler.inverse_transform(y_test_t)
print(y_pred_org[0:15])
print(y_test_t_org[0:15])
# Out:
# Error is 0.09403893710138193 (20,) (20,)
# [0.8424497  0.8264203  0.8029297  0.7783879  0.7576524  0.7294657
#  0.6776233  0.6324177  0.5826386  0.52857417 0.48308104 0.45257357
#  0.4303867  0.41020745 0.3974446 ]
# [0.98073748 0.92096871 0.9717117  0.99504681 0.91062196 0.81287837
#  0.81067697 0.76125478 0.78690148 0.78271887 0.85646677 0.84116684
#  0.83048988 0.89917459 0.80968637]
# [179.66655 178.21028 176.07616 173.84653 171.9627  169.40195 164.69208
#  160.58514 156.06271 151.15096 147.01791 144.2463  142.23062 140.39734
#  139.23784]
# [192.22999573 186.80000305 191.41000366 193.52999878 185.86000061
#  176.97999573 176.77999878 172.28999329 174.61999512 174.24000549
#  180.94000244 179.55000305 178.58000183 184.82000732 176.69000244]

# %%
y_pred
# Out:
# array([0.8424497 , 0.8264203 , 0.8029297 , 0.7783879 , 0.7576524 ,
#        0.7294657 , 0.6776233 , 0.6324177 , 0.5826386 , 0.52857417,
#        0.48308104, 0.45257357, 0.4303867 , 0.41020745, 0.3974446 ,
#        0.38289455, 0.3673172 , 0.35364357, 0.3333715 , 0.3192425 ],
#       dtype=float32)

# %%
from matplotlib import pyplot as plt

# def plotPrediction():
plt.figure()
plt.plot(y_pred_org)
plt.plot(y_test_t_org)
plt.title('Prediction vs Real Stock Price')
plt.ylabel('Price')
plt.xlabel('Days')
plt.legend(['Prediction', 'Real'], loc='upper left')
plt.show()
print("program completed ", time.time() - stime)
# Out:
# program completed  168.80866932868958

# %%
x_test_t
# Out:
# array([[[1.26188662, 1.28232365, 1.25325615, 1.23643381, 0.18716514],
#         [1.24767739, 1.25983281, 1.24123342, 1.23181065, 0.14609523],
#         [1.218166  , 1.25045213, 1.23911828, 1.23192083, 0.07503997],
#         ...,
#         [1.17313364, 1.17992766, 1.16019146, 1.15971392, 0.13816361],
#         [1.12471313, 1.13347647, 1.11009684, 1.11546511, 0.22773958],
#         [1.05312057, 1.06385635, 1.01591888, 1.00209139, 0.39458716]],
#
#        [[1.24767739, 1.25983281, 1.24123342, 1.23181065, 0.14609523],
#         [1.218166  , 1.25045213, 1.23911828, 1.23192083, 0.07503997],
#         [1.22417745, 1.25825053, 1.24757882, 1.23676401, 0.0736978 ],
#         ...,
#         [1.12471313, 1.13347647, 1.11009684, 1.11546511, 0.22773958],
#         [1.05312057, 1.06385635, 1.01591888, 1.00209139, 0.39458716],
#         [0.97256537, 1.03367988, 0.98986971, 0.98073748, 0.35227656]],
#
#        [[1.218166  , 1.25045213, 1.23911828, 1.23192083, 0.07503997],
#         [1.22417745, 1.25825053, 1.24757882, 1.23676401, 0.0736978 ],
#         [1.24549139, 1.25655513, 1.25325615, 1.24413878, 0.06965041],
#         ...,
#         [1.05312057, 1.06385635, 1.01591888, 1.00209139, 0.39458716],
#         [0.97256537, 1.03367988, 0.98986971, 0.98073748, 0.35227656],
#         [0.9973767 , 1.00316454, 0.92842026, 0.92096871, 0.49075258]],
#
#        ...,
#
#        [[1.32440713, 1.36437621, 1.34709999, 1.3408916 , 0.18610554],
#         [1.33500923, 1.35759495, 1.35244354, 1.34958735, 0.11395486],
#         [1.36954857, 1.39805609, 1.37838144, 1.3663181 , 0.12063485],
#         ...,
#         [0.6924254 , 0.69767178, 0.62963371, 0.63577329, 0.37381093],
#         [0.63121646, 0.63731919, 0.58744298, 0.59108427, 0.53027139],
#         [0.59252378, 0.59267637, 0.52432378, 0.52394055, 0.83841861]],
#
#        [[1.33500923, 1.35759495, 1.35244354, 1.34958735, 0.11395486],
#         [1.36954857, 1.39805609, 1.37838144, 1.3663181 , 0.12063485],
#         [1.36189749, 1.40461127, 1.38149843, 1.3885526 , 0.1324487 ],
#         ...,
#         [0.63121646, 0.63731919, 0.58744298, 0.59108427, 0.53027139],
#         [0.59252378, 0.59267637, 0.52432378, 0.52394055, 0.83841861],
#         [0.49732204, 0.51797021, 0.49048198, 0.48101272, 0.25563158]],
#
#        [[1.36954857, 1.39805609, 1.37838144, 1.3663181 , 0.12063485],
#         [1.36189749, 1.40461127, 1.38149843, 1.3885526 , 0.1324487 ],
#         [1.39250196, 1.44382918, 1.41656459, 1.41926266, 0.17091885],
#         ...,
#         [0.59252378, 0.59267637, 0.52432378, 0.52394055, 0.83841861],
#         [0.49732204, 0.51797021, 0.49048198, 0.48101272, 0.25563158],
#         [0.49896166, 0.58216543, 0.49192922, 0.59482666, 0.46867995]]])

# %%
# try with real testing data


y_pred = lstm_model.predict(createDataset(x_test_t, batchSize), batch_size=batchSize)
y_pred = y_pred.flatten()
y_test_t = createDataset(y_test_t, batchSize)
error = mean_squared_error(y_test_t, y_pred)
print("Error is", error, y_pred.shape, y_test_t.shape)
print(y_pred[0:15])
print(y_test_t[0:15])
y_pred_org = (y_pred * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3] # min_max_scaler.inverse_transform(y_pred)
y_test_t_org = (y_test_t * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3] # min_max_scaler.inverse_transform(y_test_t)
print(y_pred_org[0:15])
print(y_test_t_org[0:15])
# Out:
# Error is 0.07912610164296187 (20,) (20,)
# [0.83617777 0.8204777  0.79646266 0.77334285 0.75455344 0.7297134
#  0.6857352  0.6506224  0.611658   0.5672408  0.5287635  0.49909523
#  0.47687417 0.45494476 0.43941143]
# [0.98073748 0.92096871 0.9717117  0.99504681 0.91062196 0.81287837
#  0.81067697 0.76125478 0.78690148 0.78271887 0.85646677 0.84116684
#  0.83048988 0.89917459 0.80968637]
# [179.09674 177.6704  175.48862 173.38818 171.68118 169.42445 165.42905
#  162.23904 158.69913 154.66382 151.16815 148.4728  146.45401 144.46173
#  143.05052]
# [192.22999573 186.80000305 191.41000366 193.52999878 185.86000061
#  176.97999573 176.77999878 172.28999329 174.61999512 174.24000549
#  180.94000244 179.55000305 178.58000183 184.82000732 176.69000244]

# %%
# is_update_model = True
# if model is None or is_update_model:
#     from keras import backend as K
#     print("Building model...")
#     print("checking if GPU available", K.tensorflow_backend._get_available_gpus())
#     model = create_model()
    
#     es = EarlyStopping(monitor='val_loss', mode='min', verbose=1,
#                        patience=40, min_delta=0.0001)
    
#     mcp = ModelCheckpoint(os.path.join(OUTPUT_PATH,
#                           "best_model.h5"), monitor='val_loss', verbose=1,
#                           save_best_only=True, save_weights_only=False, mode='min', period=1)

#     # Not used here. But leaving it here as a reminder for future
#     r_lr_plat = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=30, 
#                                   verbose=0, mode='auto', min_delta=0.0001, cooldown=0, min_lr=0)
    
#     csv_logger = CSVLogger(os.path.join(OUTPUT_PATH, 'training_log_' + time.ctime().replace(" ","_") + '.log'), append=True)
    
#     history = model.fit(x_t, y_t, epochs=params["epochs"], verbose=2, batch_size=batchSize,
#                         shuffle=False, validation_data=(createDataset(x_val, batchSize),
#                         createDataset(y_val, batchSize)), callbacks=[es, mcp, csv_logger])
    
#     print("saving model...")
#     pickle.dump(model, open("lstm_model", "wb"))

# # model.evaluate(x_test_t, y_test_t, batch_size=batchSize
# y_pred = model.predict(createDataset(x_test_t, batchSize), batch_size=batchSize)
# y_pred = y_pred.flatten()
# y_test_t = createDataset(y_test_t, batchSize)
# error = mean_squared_error(y_test_t, y_pred)
# print("Error is", error, y_pred.shape, y_test_t.shape)
# print(y_pred[0:15])
# print(y_test_t[0:15])

# # convert the predicted value to range of real data
# y_pred_org = (y_pred * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3]
# # min_max_scaler.inverse_transform(y_pred)
# y_test_t_org = (y_test_t * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3]
# # min_max_scaler.inverse_transform(y_test_t)
# print(y_pred_org[0:15])
# print(y_test_t_org[0:15])

# # Visualize the training data
# from matplotlib import pyplot as plt
# plt.figure()
# plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
# plt.title('Model loss')
# plt.ylabel('Loss')
# plt.xlabel('Epoch')
# plt.legend(['Train', 'Test'], loc='upper left')
# #plt.show()
# plt.savefig(os.path.join(OUTPUT_PATH, 'train_vis_BS_'+str(batchSize)+"_"+time.ctime()+'.png'))

# # load the saved best model from above
# saved_model = load_model(os.path.join(OUTPUT_PATH, 'best_model.h5')) # , "lstm_best_7-3-19_12AM",
# print(saved_model)

# y_pred = saved_model.predict(createDataset(x_test_t, batchSize), batch_size=batchSize)
# y_pred = y_pred.flatten()
# y_test_t = createDataset(y_test_t, batchSize)
# error = mean_squared_error(y_test_t, y_pred)
# print("Error is", error, y_pred.shape, y_test_t.shape)
# print(y_pred[0:15])
# print(y_test_t[0:15])
# y_pred_org = (y_pred * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3] # min_max_scaler.inverse_transform(y_pred)
# y_test_t_org = (y_test_t * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3] # min_max_scaler.inverse_transform(y_test_t)
# print(y_pred_org[0:15])
# print(y_test_t_org[0:15])

# # Visualize the prediction
# from matplotlib import pyplot as plt
# plt.figure()
# plt.plot(y_pred_org)
# plt.plot(y_test_t_org)
# plt.title('Prediction vs Real Stock Price')
# plt.ylabel('Price')
# plt.xlabel('Days')
# plt.legend(['Prediction', 'Real'], loc='upper left')
# #plt.show()
# plt.savefig(os.path.join(OUTPUT_PATH, 'pred_vs_real_BS'+str(batchSize)+"_"+time.ctime()+'.png'))
# print_time("program completed ", stime)
