# %%
# Author: Roshan Ram
# AndrewID: rram

import yfinance as yfinance

import module_manager
module_manager.review()

import yfinance as yf # to pull stock data with yf.download(name, yyyy-mm-dd of opening, yyyy-mm-dd of opening)

import numpy as np # used for everything lol
import pandas as pd # data mainpulation
import matplotlib.pyplot as plt # graphing/plotting
from keras import *


#####
import numpy as np
import os
import sys
import time
import pandas as pd 
from tqdm._tqdm_notebook import tqdm_notebook
import pickle
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout
from keras.layers import LSTM
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger
from keras import optimizers
# from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import logging
####

# %matplotlib inline 
#just to make stuff look nice
# Out:
# Using TensorFlow backend.

# %%
stock = None
while not isinstance(stock, str):
    stock = input("Enter your desired stock. Only alphanumeric characters please.")
openingInp = input("Enter your desired opening date. (yyyy-mm-dd)") #'2016-01-01'
closingInp = input("Enter your desired closing date. (yyyy-mm-dd)") # '2019-08-01'


data = yf.download(stock, openingInp, closingInp)
# Out:
# Enter your desired stock. Only alphanumeric characters please.AAPL
# Enter your desired opening date. (yyyy-mm-dd)2016-08-01
# Enter your desired closing date. (yyyy-mm-dd)2019-11-01
# [*********************100%***********************]  1 of 1 completed

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

TIME_STEPS = 10 # [rram]
BATCH_SIZE = 32 # [rram]


#####
params = {
    "batch_size": 20,  # 20<16<10, 25 was a bust
    "epochs": 300,
    "lr": 0.00010000,
    "time_steps": 60
}

iter_changes = "dropout_layers_0.4_0.4"

# INPUT_PATH = PATH_TO_DRIVE_ML_DATA+"/inputs"
OUTPUT_PATH = '~/Desktop'
TIME_STEPS = params["time_steps"]
BATCH_SIZE = params["batch_size"]
stime = time.time()
###


train_cols = ["Open","High","Low","Close","Volume"]
df_train, df_test = train_test_split(data, train_size=0.8, test_size=0.2, shuffle=False)
print("Train and Test size", len(df_train), len(df_test))
# scale the feature MinMax, build array
x = df_train.loc[:,train_cols].values
min_max_scaler = MinMaxScaler()
x_train = min_max_scaler.fit_transform(x)
x_test = min_max_scaler.transform(df_test.loc[:,train_cols])
# Out:
# Train and Test size 656 165

# %%
def build_timeseries(mat, y_col_index):
    # y_col_index is the index of column that would act as output column
    # total number of time-series samples would be len(mat) - TIME_STEPS
    dim_0 = mat.shape[0] - TIME_STEPS
    dim_1 = mat.shape[1]
    x = np.zeros((dim_0, TIME_STEPS, dim_1))
    y = np.zeros((dim_0,))
    
    for i in (range(dim_0)):
        x[i] = mat[i:TIME_STEPS+i]
        y[i] = mat[TIME_STEPS+i, y_col_index]
    print("length of time-series i/o",x.shape,y.shape)
    return x, y

# %%
def trim_dataset(mat, batch_size):
    """
    trims dataset to a size that's divisible by BATCH_SIZE
    """
    no_of_rows_drop = mat.shape[0]%batch_size
    if(no_of_rows_drop > 0):
        return mat[:-no_of_rows_drop]
    else:
        return mat

# %%
x_t, y_t = build_timeseries(x_train, 3)
x_t = trim_dataset(x_t, BATCH_SIZE)
y_t = trim_dataset(y_t, BATCH_SIZE)
x_temp, y_temp = build_timeseries(x_test, 3)
x_val, x_test_t = np.split(trim_dataset(x_temp, BATCH_SIZE),2)
y_val, y_test_t = np.split(trim_dataset(y_temp, BATCH_SIZE),2)
# Out:
# length of time-series i/o (596, 60, 5) (596,)
# length of time-series i/o (105, 60, 5) (105,)

# %%
# def create_model():
lstm_model = Sequential()
lstm_model.add(LSTM(100, batch_input_shape=(BATCH_SIZE, TIME_STEPS, x_t.shape[2]), dropout=0.0, recurrent_dropout=0.0, stateful=True,     kernel_initializer='random_uniform'))
lstm_model.add(Dropout(0.5))
lstm_model.add(Dense(20,activation='relu'))
lstm_model.add(Dense(1,activation='sigmoid'))
optimizer = optimizers.RMSprop(lr=0.00010000)
lstm_model.compile(loss='mean_squared_error', optimizer=optimizer)

# %%
model = lstm_model

# %%
csv_logger = CSVLogger(os.path.join(OUTPUT_PATH, 'your_log_name' + '.log'), append=True)

# epochs = params['epochs']

history = model.fit(x_t, y_t, epochs= 300, verbose=2, batch_size=BATCH_SIZE,
                    shuffle=False, validation_data=(trim_dataset(x_val, BATCH_SIZE),
                    trim_dataset(y_val, BATCH_SIZE))) #callbacks=[csv_logger])

# history = model.fit(x_t, y_t, epochs=params["epochs"], verbose=2, batch_size=BATCH_SIZE,
#                         shuffle=False, validation_data=(trim_dataset(x_val, BATCH_SIZE),
#                         trim_dataset(y_val, BATCH_SIZE)), callbacks=[es, mcp, csv_logger])
# Out:
# Train on 580 samples, validate on 40 samples
# Epoch 1/300
#  - 2s - loss: 0.0519 - val_loss: 0.0687
# Epoch 2/300
#  - 1s - loss: 0.0494 - val_loss: 0.0567
# Epoch 3/300
#  - 1s - loss: 0.0475 - val_loss: 0.0475
# Epoch 4/300
#  - 1s - loss: 0.0459 - val_loss: 0.0389
# Epoch 5/300
#  - 1s - loss: 0.0441 - val_loss: 0.0308
# Epoch 6/300
#  - 1s - loss: 0.0426 - val_loss: 0.0234
# Epoch 7/300
#  - 1s - loss: 0.0401 - val_loss: 0.0175
# Epoch 8/300
#  - 1s - loss: 0.0387 - val_loss: 0.0128
# Epoch 9/300
#  - 1s - loss: 0.0362 - val_loss: 0.0095
# Epoch 10/300
#  - 1s - loss: 0.0335 - val_loss: 0.0076
# Epoch 11/300
#  - 1s - loss: 0.0309 - val_loss: 0.0081
# Epoch 12/300
#  - 1s - loss: 0.0284 - val_loss: 0.0077
# Epoch 13/300
#  - 1s - loss: 0.0260 - val_loss: 0.0074
# Epoch 14/300
#  - 1s - loss: 0.0242 - val_loss: 0.0067
# Epoch 15/300
#  - 1s - loss: 0.0222 - val_loss: 0.0064
# Epoch 16/300
#  - 1s - loss: 0.0200 - val_loss: 0.0050
# Epoch 17/300
#  - 1s - loss: 0.0175 - val_loss: 0.0037
# Epoch 18/300
#  - 1s - loss: 0.0152 - val_loss: 0.0037
# Epoch 19/300
#  - 1s - loss: 0.0134 - val_loss: 0.0038
# Epoch 20/300
#  - 1s - loss: 0.0123 - val_loss: 0.0034
# Epoch 21/300
#  - 1s - loss: 0.0119 - val_loss: 0.0031
# Epoch 22/300
#  - 1s - loss: 0.0118 - val_loss: 0.0029
# Epoch 23/300
#  - 1s - loss: 0.0107 - val_loss: 0.0031
# Epoch 24/300
#  - 1s - loss: 0.0105 - val_loss: 0.0028
# Epoch 25/300
#  - 1s - loss: 0.0101 - val_loss: 0.0025
# Epoch 26/300
#  - 1s - loss: 0.0103 - val_loss: 0.0021
# Epoch 27/300
#  - 1s - loss: 0.0099 - val_loss: 0.0024
# Epoch 28/300
#  - 1s - loss: 0.0093 - val_loss: 0.0023
# Epoch 29/300
#  - 1s - loss: 0.0089 - val_loss: 0.0019
# Epoch 30/300
#  - 1s - loss: 0.0089 - val_loss: 0.0017
# Epoch 31/300
#  - 1s - loss: 0.0087 - val_loss: 0.0016
# Epoch 32/300
#  - 1s - loss: 0.0085 - val_loss: 0.0015
# Epoch 33/300
#  - 1s - loss: 0.0086 - val_loss: 0.0017
# Epoch 34/300
#  - 1s - loss: 0.0080 - val_loss: 0.0016
# Epoch 35/300
#  - 1s - loss: 0.0084 - val_loss: 0.0015
# Epoch 36/300
#  - 1s - loss: 0.0077 - val_loss: 0.0012
# Epoch 37/300
#  - 1s - loss: 0.0074 - val_loss: 0.0014
# Epoch 38/300
#  - 1s - loss: 0.0070 - val_loss: 0.0015
# Epoch 39/300
#  - 1s - loss: 0.0067 - val_loss: 0.0013
# Epoch 40/300
#  - 1s - loss: 0.0075 - val_loss: 0.0012
# Epoch 41/300
#  - 1s - loss: 0.0070 - val_loss: 0.0011
# Epoch 42/300
#  - 1s - loss: 0.0074 - val_loss: 0.0010
# Epoch 43/300
#  - 1s - loss: 0.0070 - val_loss: 0.0011
# Epoch 44/300
#  - 1s - loss: 0.0067 - val_loss: 0.0011
# Epoch 45/300
#  - 1s - loss: 0.0063 - val_loss: 0.0014
# Epoch 46/300
#  - 1s - loss: 0.0066 - val_loss: 8.8642e-04
# Epoch 47/300
#  - 1s - loss: 0.0066 - val_loss: 9.0301e-04
# Epoch 48/300
#  - 1s - loss: 0.0066 - val_loss: 0.0011
# Epoch 49/300
#  - 1s - loss: 0.0064 - val_loss: 0.0011
# Epoch 50/300
#  - 1s - loss: 0.0062 - val_loss: 8.6263e-04
# Epoch 51/300
#  - 1s - loss: 0.0063 - val_loss: 9.5391e-04
# Epoch 52/300
#  - 1s - loss: 0.0059 - val_loss: 0.0010
# Epoch 53/300
#  - 1s - loss: 0.0063 - val_loss: 8.1420e-04
# Epoch 54/300
#  - 1s - loss: 0.0057 - val_loss: 9.2178e-04
# Epoch 55/300
#  - 1s - loss: 0.0062 - val_loss: 8.3489e-04
# Epoch 56/300
#  - 1s - loss: 0.0058 - val_loss: 9.3619e-04
# Epoch 57/300
#  - 1s - loss: 0.0057 - val_loss: 0.0010
# Epoch 58/300
#  - 1s - loss: 0.0057 - val_loss: 9.7063e-04
# Epoch 59/300
#  - 1s - loss: 0.0058 - val_loss: 9.1060e-04
# Epoch 60/300
#  - 1s - loss: 0.0055 - val_loss: 9.5803e-04
# Epoch 61/300
#  - 1s - loss: 0.0056 - val_loss: 7.9257e-04
# Epoch 62/300
#  - 1s - loss: 0.0056 - val_loss: 8.7492e-04
# Epoch 63/300
#  - 1s - loss: 0.0055 - val_loss: 9.1365e-04
# Epoch 64/300
#  - 1s - loss: 0.0058 - val_loss: 9.8775e-04
# Epoch 65/300
#  - 1s - loss: 0.0054 - val_loss: 0.0011
# Epoch 66/300
#  - 1s - loss: 0.0055 - val_loss: 8.2832e-04
# Epoch 67/300
#  - 1s - loss: 0.0051 - val_loss: 8.4128e-04
# Epoch 68/300
#  - 1s - loss: 0.0053 - val_loss: 9.4508e-04
# Epoch 69/300
#  - 1s - loss: 0.0057 - val_loss: 7.8511e-04
# Epoch 70/300
#  - 1s - loss: 0.0054 - val_loss: 0.0010
# Epoch 71/300
#  - 1s - loss: 0.0054 - val_loss: 9.8056e-04
# Epoch 72/300
#  - 1s - loss: 0.0053 - val_loss: 9.4758e-04
# Epoch 73/300
#  - 1s - loss: 0.0050 - val_loss: 8.9402e-04
# Epoch 74/300
#  - 1s - loss: 0.0051 - val_loss: 8.5165e-04
# Epoch 75/300
#  - 1s - loss: 0.0048 - val_loss: 7.1234e-04
# Epoch 76/300
#  - 1s - loss: 0.0049 - val_loss: 8.6334e-04
# Epoch 77/300
#  - 1s - loss: 0.0046 - val_loss: 7.6388e-04
# Epoch 78/300
#  - 1s - loss: 0.0046 - val_loss: 7.2090e-04
# Epoch 79/300
#  - 1s - loss: 0.0044 - val_loss: 7.1415e-04
# Epoch 80/300
#  - 1s - loss: 0.0047 - val_loss: 7.2535e-04
# Epoch 81/300
#  - 1s - loss: 0.0047 - val_loss: 5.9789e-04
# Epoch 82/300
#  - 1s - loss: 0.0043 - val_loss: 6.8717e-04
# Epoch 83/300
#  - 1s - loss: 0.0041 - val_loss: 6.0752e-04
# Epoch 84/300
#  - 1s - loss: 0.0043 - val_loss: 7.5572e-04
# Epoch 85/300
#  - 1s - loss: 0.0042 - val_loss: 9.6779e-04
# Epoch 86/300
#  - 1s - loss: 0.0043 - val_loss: 0.0012
# Epoch 87/300
#  - 1s - loss: 0.0045 - val_loss: 7.3221e-04
# Epoch 88/300
#  - 1s - loss: 0.0044 - val_loss: 5.1467e-04
# Epoch 89/300
#  - 1s - loss: 0.0044 - val_loss: 4.9589e-04
# Epoch 90/300
#  - 1s - loss: 0.0042 - val_loss: 6.4646e-04
# Epoch 91/300
#  - 1s - loss: 0.0042 - val_loss: 5.4946e-04
# Epoch 92/300
#  - 1s - loss: 0.0041 - val_loss: 0.0011
# Epoch 93/300
#  - 1s - loss: 0.0041 - val_loss: 6.4880e-04
# Epoch 94/300
#  - 1s - loss: 0.0039 - val_loss: 6.6092e-04
# Epoch 95/300
#  - 1s - loss: 0.0040 - val_loss: 5.5374e-04
# Epoch 96/300
#  - 1s - loss: 0.0039 - val_loss: 5.5618e-04
# Epoch 97/300
#  - 1s - loss: 0.0039 - val_loss: 0.0010
# Epoch 98/300
#  - 1s - loss: 0.0039 - val_loss: 8.7992e-04
# Epoch 99/300
#  - 1s - loss: 0.0036 - val_loss: 7.8711e-04
# Epoch 100/300
#  - 1s - loss: 0.0040 - val_loss: 8.8982e-04
# Epoch 101/300
#  - 1s - loss: 0.0039 - val_loss: 5.7705e-04
# Epoch 102/300
#  - 1s - loss: 0.0037 - val_loss: 7.8907e-04
# Epoch 103/300
#  - 1s - loss: 0.0038 - val_loss: 7.0100e-04
# Epoch 104/300
#  - 1s - loss: 0.0037 - val_loss: 9.2101e-04
# Epoch 105/300
#  - 1s - loss: 0.0036 - val_loss: 6.5225e-04
# Epoch 106/300
#  - 1s - loss: 0.0036 - val_loss: 5.9434e-04
# Epoch 107/300
#  - 1s - loss: 0.0036 - val_loss: 6.6098e-04
# Epoch 108/300
#  - 1s - loss: 0.0037 - val_loss: 7.3875e-04
# Epoch 109/300
#  - 1s - loss: 0.0036 - val_loss: 0.0011
# Epoch 110/300
#  - 1s - loss: 0.0034 - val_loss: 8.3066e-04
# Epoch 111/300
#  - 1s - loss: 0.0034 - val_loss: 0.0013
# Epoch 112/300
#  - 1s - loss: 0.0034 - val_loss: 0.0011
# Epoch 113/300
#  - 1s - loss: 0.0035 - val_loss: 9.3469e-04
# Epoch 114/300
#  - 1s - loss: 0.0034 - val_loss: 7.8029e-04
# Epoch 115/300
#  - 1s - loss: 0.0036 - val_loss: 8.3834e-04
# Epoch 116/300
#  - 1s - loss: 0.0028 - val_loss: 0.0010
# Epoch 117/300
#  - 1s - loss: 0.0031 - val_loss: 8.6309e-04
# Epoch 118/300
#  - 1s - loss: 0.0033 - val_loss: 9.7882e-04
# Epoch 119/300
#  - 1s - loss: 0.0034 - val_loss: 0.0013
# Epoch 120/300
#  - 1s - loss: 0.0033 - val_loss: 0.0011
# Epoch 121/300
#  - 1s - loss: 0.0031 - val_loss: 8.0129e-04
# Epoch 122/300
#  - 1s - loss: 0.0032 - val_loss: 9.1099e-04
# Epoch 123/300
#  - 1s - loss: 0.0029 - val_loss: 8.5431e-04
# Epoch 124/300
#  - 1s - loss: 0.0033 - val_loss: 0.0012
# Epoch 125/300
#  - 1s - loss: 0.0030 - val_loss: 0.0011
# Epoch 126/300
#  - 1s - loss: 0.0028 - val_loss: 8.5399e-04
# Epoch 127/300
#  - 1s - loss: 0.0030 - val_loss: 8.4061e-04
# Epoch 128/300
#  - 1s - loss: 0.0028 - val_loss: 0.0011
# Epoch 129/300
#  - 1s - loss: 0.0030 - val_loss: 0.0014
# Epoch 130/300
#  - 1s - loss: 0.0029 - val_loss: 9.5323e-04
# Epoch 131/300
#  - 1s - loss: 0.0027 - val_loss: 9.0400e-04
# Epoch 132/300
#  - 1s - loss: 0.0032 - val_loss: 0.0011
# Epoch 133/300
#  - 1s - loss: 0.0030 - val_loss: 9.0416e-04
# Epoch 134/300
#  - 1s - loss: 0.0028 - val_loss: 0.0011
# Epoch 135/300
#  - 1s - loss: 0.0029 - val_loss: 9.6805e-04
# Epoch 136/300
#  - 1s - loss: 0.0027 - val_loss: 8.2956e-04
# Epoch 137/300
#  - 1s - loss: 0.0028 - val_loss: 9.6324e-04
# Epoch 138/300
#  - 1s - loss: 0.0029 - val_loss: 9.4360e-04
# Epoch 139/300
#  - 1s - loss: 0.0028 - val_loss: 0.0017
# Epoch 140/300
#  - 1s - loss: 0.0031 - val_loss: 0.0016
# Epoch 141/300
#  - 1s - loss: 0.0025 - val_loss: 0.0011
# Epoch 142/300
#  - 1s - loss: 0.0026 - val_loss: 0.0010
# Epoch 143/300
#  - 1s - loss: 0.0030 - val_loss: 0.0012
# Epoch 144/300
#  - 1s - loss: 0.0028 - val_loss: 0.0011
# Epoch 145/300
#  - 1s - loss: 0.0028 - val_loss: 0.0010
# Epoch 146/300
#  - 1s - loss: 0.0028 - val_loss: 0.0011
# Epoch 147/300
#  - 1s - loss: 0.0027 - val_loss: 0.0011
# Epoch 148/300
#  - 1s - loss: 0.0027 - val_loss: 0.0011
# Epoch 149/300
#  - 1s - loss: 0.0028 - val_loss: 0.0011
# Epoch 150/300
#  - 1s - loss: 0.0028 - val_loss: 9.7564e-04
# Epoch 151/300
#  - 1s - loss: 0.0026 - val_loss: 0.0010
# Epoch 152/300
#  - 1s - loss: 0.0026 - val_loss: 0.0011
# Epoch 153/300
#  - 1s - loss: 0.0027 - val_loss: 0.0011
# Epoch 154/300
#  - 1s - loss: 0.0026 - val_loss: 0.0012
# Epoch 155/300
#  - 1s - loss: 0.0025 - val_loss: 0.0011
# Epoch 156/300
#  - 1s - loss: 0.0026 - val_loss: 0.0011
# Epoch 157/300
#  - 1s - loss: 0.0027 - val_loss: 0.0016
# Epoch 158/300
#  - 1s - loss: 0.0026 - val_loss: 0.0011
# Epoch 159/300
#  - 1s - loss: 0.0029 - val_loss: 0.0015
# Epoch 160/300
#  - 1s - loss: 0.0025 - val_loss: 0.0012
# Epoch 161/300
#  - 1s - loss: 0.0025 - val_loss: 0.0012
# Epoch 162/300
#  - 1s - loss: 0.0026 - val_loss: 0.0011
# Epoch 163/300
#  - 1s - loss: 0.0025 - val_loss: 0.0012
# Epoch 164/300
#  - 1s - loss: 0.0025 - val_loss: 0.0013
# Epoch 165/300
#  - 1s - loss: 0.0025 - val_loss: 0.0012
# Epoch 166/300
#  - 1s - loss: 0.0024 - val_loss: 0.0012
# Epoch 167/300
#  - 1s - loss: 0.0025 - val_loss: 0.0011
# Epoch 168/300
#  - 1s - loss: 0.0026 - val_loss: 0.0012
# Epoch 169/300
#  - 1s - loss: 0.0023 - val_loss: 0.0013
# Epoch 170/300
#  - 1s - loss: 0.0023 - val_loss: 0.0013
# Epoch 171/300
#  - 1s - loss: 0.0025 - val_loss: 0.0013
# Epoch 172/300
#  - 1s - loss: 0.0023 - val_loss: 0.0014
# Epoch 173/300
#  - 1s - loss: 0.0023 - val_loss: 0.0012
# Epoch 174/300
#  - 1s - loss: 0.0022 - val_loss: 0.0012
# Epoch 175/300
#  - 1s - loss: 0.0022 - val_loss: 0.0013
# Epoch 176/300
#  - 1s - loss: 0.0024 - val_loss: 0.0012
# Epoch 177/300
#  - 1s - loss: 0.0024 - val_loss: 0.0014
# Epoch 178/300
#  - 1s - loss: 0.0021 - val_loss: 0.0017
# Epoch 179/300
#  - 1s - loss: 0.0026 - val_loss: 0.0017
# Epoch 180/300
#  - 1s - loss: 0.0021 - val_loss: 0.0014
# Epoch 181/300
#  - 1s - loss: 0.0024 - val_loss: 0.0013
# Epoch 182/300
#  - 1s - loss: 0.0022 - val_loss: 0.0012
# Epoch 183/300
#  - 1s - loss: 0.0024 - val_loss: 0.0011
# Epoch 184/300
#  - 1s - loss: 0.0023 - val_loss: 0.0024
# Epoch 185/300
#  - 1s - loss: 0.0022 - val_loss: 0.0018
# Epoch 186/300
#  - 1s - loss: 0.0021 - val_loss: 0.0015
# Epoch 187/300
#  - 1s - loss: 0.0022 - val_loss: 0.0012
# Epoch 188/300
#  - 1s - loss: 0.0023 - val_loss: 0.0012
# Epoch 189/300
#  - 1s - loss: 0.0022 - val_loss: 0.0011
# Epoch 190/300
#  - 1s - loss: 0.0020 - val_loss: 0.0012
# Epoch 191/300
#  - 1s - loss: 0.0023 - val_loss: 0.0011
# Epoch 192/300
#  - 1s - loss: 0.0021 - val_loss: 0.0012
# Epoch 193/300
#  - 1s - loss: 0.0024 - val_loss: 0.0015
# Epoch 194/300
#  - 1s - loss: 0.0022 - val_loss: 0.0012
# Epoch 195/300
#  - 1s - loss: 0.0021 - val_loss: 0.0015
# Epoch 196/300
#  - 1s - loss: 0.0019 - val_loss: 0.0013
# Epoch 197/300
#  - 1s - loss: 0.0024 - val_loss: 0.0012
# Epoch 198/300
#  - 1s - loss: 0.0021 - val_loss: 0.0019
# Epoch 199/300
#  - 1s - loss: 0.0021 - val_loss: 0.0013
# Epoch 200/300
#  - 1s - loss: 0.0021 - val_loss: 0.0014
# Epoch 201/300
#  - 1s - loss: 0.0020 - val_loss: 0.0015
# Epoch 202/300
#  - 1s - loss: 0.0020 - val_loss: 0.0015
# Epoch 203/300
#  - 1s - loss: 0.0021 - val_loss: 0.0014
# Epoch 204/300
#  - 1s - loss: 0.0023 - val_loss: 0.0014
# Epoch 205/300
#  - 1s - loss: 0.0020 - val_loss: 0.0011
# Epoch 206/300
#  - 1s - loss: 0.0020 - val_loss: 0.0011
# Epoch 207/300
#  - 1s - loss: 0.0021 - val_loss: 0.0011
# Epoch 208/300
#  - 1s - loss: 0.0020 - val_loss: 0.0010
# Epoch 209/300
#  - 1s - loss: 0.0020 - val_loss: 0.0013
# Epoch 210/300
#  - 1s - loss: 0.0020 - val_loss: 0.0013
# Epoch 211/300
#  - 1s - loss: 0.0019 - val_loss: 0.0012
# Epoch 212/300
#  - 1s - loss: 0.0020 - val_loss: 0.0013
# Epoch 213/300
#  - 1s - loss: 0.0020 - val_loss: 0.0015
# Epoch 214/300
#  - 1s - loss: 0.0021 - val_loss: 0.0013
# Epoch 215/300
#  - 1s - loss: 0.0022 - val_loss: 9.8327e-04
# Epoch 216/300
#  - 1s - loss: 0.0021 - val_loss: 0.0012
# Epoch 217/300
#  - 1s - loss: 0.0020 - val_loss: 0.0015
# Epoch 218/300
#  - 1s - loss: 0.0019 - val_loss: 0.0013
# Epoch 219/300
#  - 1s - loss: 0.0019 - val_loss: 0.0014
# Epoch 220/300
#  - 1s - loss: 0.0020 - val_loss: 0.0014
# Epoch 221/300
#  - 1s - loss: 0.0019 - val_loss: 0.0011
# Epoch 222/300
#  - 1s - loss: 0.0021 - val_loss: 0.0010
# Epoch 223/300
#  - 1s - loss: 0.0019 - val_loss: 0.0011
# Epoch 224/300
#  - 1s - loss: 0.0019 - val_loss: 0.0012
# Epoch 225/300
#  - 1s - loss: 0.0020 - val_loss: 0.0011
# Epoch 226/300
#  - 1s - loss: 0.0019 - val_loss: 0.0012
# Epoch 227/300
#  - 1s - loss: 0.0018 - val_loss: 0.0010
# Epoch 228/300
#  - 1s - loss: 0.0020 - val_loss: 0.0010
# Epoch 229/300
#  - 1s - loss: 0.0019 - val_loss: 0.0011
# Epoch 230/300
#  - 1s - loss: 0.0019 - val_loss: 0.0014
# Epoch 231/300
#  - 1s - loss: 0.0020 - val_loss: 0.0012
# Epoch 232/300
#  - 1s - loss: 0.0020 - val_loss: 9.4848e-04
# Epoch 233/300
#  - 1s - loss: 0.0018 - val_loss: 0.0013
# Epoch 234/300
#  - 1s - loss: 0.0019 - val_loss: 0.0013
# Epoch 235/300
#  - 1s - loss: 0.0019 - val_loss: 0.0012
# Epoch 236/300
#  - 1s - loss: 0.0019 - val_loss: 9.6421e-04
# Epoch 237/300
#  - 1s - loss: 0.0019 - val_loss: 9.1700e-04
# Epoch 238/300
#  - 1s - loss: 0.0018 - val_loss: 0.0017
# Epoch 239/300
#  - 1s - loss: 0.0019 - val_loss: 9.5969e-04
# Epoch 240/300
#  - 1s - loss: 0.0017 - val_loss: 0.0010
# Epoch 241/300
#  - 1s - loss: 0.0017 - val_loss: 7.7608e-04
# Epoch 242/300
#  - 1s - loss: 0.0021 - val_loss: 7.6777e-04
# Epoch 243/300
#  - 1s - loss: 0.0017 - val_loss: 0.0018
# Epoch 244/300
#  - 1s - loss: 0.0018 - val_loss: 0.0012
# Epoch 245/300
#  - 1s - loss: 0.0017 - val_loss: 9.1139e-04
# Epoch 246/300
#  - 1s - loss: 0.0019 - val_loss: 0.0014
# Epoch 247/300
#  - 1s - loss: 0.0017 - val_loss: 0.0012
# Epoch 248/300
#  - 1s - loss: 0.0017 - val_loss: 8.8488e-04
# Epoch 249/300
#  - 1s - loss: 0.0018 - val_loss: 0.0013
# Epoch 250/300
#  - 1s - loss: 0.0020 - val_loss: 0.0017
# Epoch 251/300
#  - 1s - loss: 0.0018 - val_loss: 0.0017
# Epoch 252/300
#  - 1s - loss: 0.0018 - val_loss: 0.0014
# Epoch 253/300
#  - 1s - loss: 0.0016 - val_loss: 0.0014
# Epoch 254/300
#  - 1s - loss: 0.0018 - val_loss: 0.0012
# Epoch 255/300
#  - 1s - loss: 0.0018 - val_loss: 0.0011
# Epoch 256/300
#  - 1s - loss: 0.0017 - val_loss: 9.2114e-04
# Epoch 257/300
#  - 1s - loss: 0.0017 - val_loss: 0.0011
# Epoch 258/300
#  - 1s - loss: 0.0017 - val_loss: 0.0010
# Epoch 259/300
#  - 1s - loss: 0.0017 - val_loss: 0.0013
# Epoch 260/300
#  - 1s - loss: 0.0017 - val_loss: 0.0011
# Epoch 261/300
#  - 1s - loss: 0.0018 - val_loss: 6.8921e-04
# Epoch 262/300
#  - 1s - loss: 0.0018 - val_loss: 9.3252e-04
# Epoch 263/300
#  - 1s - loss: 0.0016 - val_loss: 9.3607e-04
# Epoch 264/300
#  - 1s - loss: 0.0018 - val_loss: 0.0011
# Epoch 265/300
#  - 1s - loss: 0.0016 - val_loss: 0.0011
# Epoch 266/300
#  - 1s - loss: 0.0018 - val_loss: 0.0011
# Epoch 267/300
#  - 1s - loss: 0.0018 - val_loss: 0.0019
# Epoch 268/300
#  - 1s - loss: 0.0017 - val_loss: 0.0016
# Epoch 269/300
#  - 1s - loss: 0.0017 - val_loss: 0.0013
# Epoch 270/300
#  - 1s - loss: 0.0018 - val_loss: 7.6075e-04
# Epoch 271/300
#  - 1s - loss: 0.0017 - val_loss: 9.3845e-04
# Epoch 272/300
#  - 1s - loss: 0.0018 - val_loss: 6.4760e-04
# Epoch 273/300
#  - 1s - loss: 0.0017 - val_loss: 0.0013
# Epoch 274/300
#  - 1s - loss: 0.0017 - val_loss: 0.0010
# Epoch 275/300
#  - 1s - loss: 0.0017 - val_loss: 0.0010
# Epoch 276/300
#  - 1s - loss: 0.0017 - val_loss: 7.3568e-04
# Epoch 277/300
#  - 1s - loss: 0.0017 - val_loss: 0.0012
# Epoch 278/300
#  - 1s - loss: 0.0018 - val_loss: 9.6128e-04
# Epoch 279/300
#  - 1s - loss: 0.0018 - val_loss: 0.0011
# Epoch 280/300
#  - 1s - loss: 0.0018 - val_loss: 0.0015
# Epoch 281/300
#  - 1s - loss: 0.0016 - val_loss: 0.0011
# Epoch 282/300
#  - 1s - loss: 0.0017 - val_loss: 6.0288e-04
# Epoch 283/300
#  - 1s - loss: 0.0019 - val_loss: 0.0024
# Epoch 284/300
#  - 1s - loss: 0.0017 - val_loss: 0.0018
# Epoch 285/300
#  - 1s - loss: 0.0016 - val_loss: 0.0017
# Epoch 286/300
#  - 1s - loss: 0.0017 - val_loss: 7.8226e-04
# Epoch 287/300
#  - 1s - loss: 0.0017 - val_loss: 7.3564e-04
# Epoch 288/300
#  - 1s - loss: 0.0016 - val_loss: 9.2670e-04
# Epoch 289/300
#  - 1s - loss: 0.0015 - val_loss: 0.0012
# Epoch 290/300
#  - 1s - loss: 0.0017 - val_loss: 9.1431e-04
# Epoch 291/300
#  - 1s - loss: 0.0018 - val_loss: 9.0187e-04
# Epoch 292/300
#  - 1s - loss: 0.0018 - val_loss: 7.8689e-04
# Epoch 293/300
#  - 1s - loss: 0.0018 - val_loss: 9.4394e-04
# Epoch 294/300
#  - 1s - loss: 0.0017 - val_loss: 8.0226e-04
# Epoch 295/300
#  - 1s - loss: 0.0017 - val_loss: 0.0010
# Epoch 296/300
#  - 1s - loss: 0.0017 - val_loss: 6.8707e-04
# Epoch 297/300
#  - 1s - loss: 0.0016 - val_loss: 6.0940e-04
# Epoch 298/300
#  - 1s - loss: 0.0016 - val_loss: 0.0011
# Epoch 299/300
#  - 1s - loss: 0.0017 - val_loss: 7.2301e-04
# Epoch 300/300
#  - 1s - loss: 0.0016 - val_loss: 0.0014

# %%
y_pred = model.predict(trim_dataset(x_test_t, BATCH_SIZE), batch_size=BATCH_SIZE)
y_pred = y_pred.flatten()
y_test_t = trim_dataset(y_test_t, BATCH_SIZE)
error = mean_squared_error(y_test_t, y_pred)
print("Error is", error, y_pred.shape, y_test_t.shape)
print(y_pred[0:15])
print(y_test_t[0:15])

# convert the predicted value to range of real data
y_pred_org = (y_pred * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3]
# min_max_scaler.inverse_transform(y_pred)
y_test_t_org = (y_test_t * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3]
# min_max_scaler.inverse_transform(y_test_t)
print(y_pred_org[0:15])
print(y_test_t_org[0:15])

# Visualize the training data
from matplotlib import pyplot as plt
plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
#plt.show()
# Out:
# Error is 0.0023840355540492206 (40,) (40,)
# [0.8223127  0.8203469  0.82088906 0.82092524 0.8216429  0.82165474
#  0.81645197 0.8128146  0.80896497 0.80445576 0.802724   0.801768
#  0.7984916  0.7982112  0.80090624]
# [0.80169067 0.83154956 0.83162707 0.84930971 0.84791377 0.77175426
#  0.80161315 0.78354272 0.79416778 0.82115704 0.81906313 0.79548621
#  0.8225531  0.85427325 0.85411811]
# [209.159   208.90552 208.97543 208.9801  209.07263 209.07416 208.40332
#  207.93431 207.43794 206.85652 206.63324 206.50996 206.08751 206.05136
#  206.39885]
# [206.5        210.3500061  210.36000061 212.63999939 212.46000671
#  202.63999939 206.49000549 204.16000366 205.52999878 209.00999451
#  208.74000549 205.69999695 209.19000244 213.27999878 213.25999451]

# %%
y_pred = lstm_model.predict(trim_dataset(x_test_t, BATCH_SIZE), batch_size=BATCH_SIZE)
y_pred = y_pred.flatten()
y_test_t = trim_dataset(y_test_t, BATCH_SIZE)
error = mean_squared_error(y_test_t, y_pred)
print("Error is", error, y_pred.shape, y_test_t.shape)
print(y_pred[0:15])
print(y_test_t[0:15])
y_pred_org = (y_pred * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3] # min_max_scaler.inverse_transform(y_pred)
y_test_t_org = (y_test_t * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3] # min_max_scaler.inverse_transform(y_test_t)
print(y_pred_org[0:15])
print(y_test_t_org[0:15])
# Out:
# Error is 0.0027939377860026985 (40,) (40,)
# [0.8486229  0.85078317 0.8553791  0.858932   0.8629442  0.86595607
#  0.86516935 0.86533785 0.8654944  0.86540794 0.86621845 0.86676204
#  0.86595416 0.8662877  0.86782897]
# [0.80169067 0.83154956 0.83162707 0.84930971 0.84791377 0.77175426
#  0.80161315 0.78354272 0.79416778 0.82115704 0.81906313 0.79548621
#  0.8225531  0.85427325 0.85411811]
# [212.55144 212.82999 213.42258 213.88069 214.39803 214.78638 214.68494
#  214.70667 214.72684 214.7157  214.8202  214.89029 214.78613 214.82913
#  215.02786]
# [206.5        210.3500061  210.36000061 212.63999939 212.46000671
#  202.63999939 206.49000549 204.16000366 205.52999878 209.00999451
#  208.74000549 205.69999695 209.19000244 213.27999878 213.25999451]

# %%
from matplotlib import pyplot as plt
plt.figure()
plt.plot(y_pred_org)
plt.plot(y_test_t_org)
plt.title('Prediction vs Real Stock Price')
plt.ylabel('Price')
plt.xlabel('Days')
plt.legend(['Prediction', 'Real'], loc='upper left')
#plt.show()
print_time("program completed ", stime)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-d971dae40d2f> in <module>
#       8 plt.legend(['Prediction', 'Real'], loc='upper left')
#       9 #plt.show()
# ---> 10 print_time("program completed ", stime)
#
# NameError: name 'print_time' is not defined

# %%
# is_update_model = True
# if model is None or is_update_model:
#     from keras import backend as K
#     print("Building model...")
#     print("checking if GPU available", K.tensorflow_backend._get_available_gpus())
#     model = create_model()
    
#     es = EarlyStopping(monitor='val_loss', mode='min', verbose=1,
#                        patience=40, min_delta=0.0001)
    
#     mcp = ModelCheckpoint(os.path.join(OUTPUT_PATH,
#                           "best_model.h5"), monitor='val_loss', verbose=1,
#                           save_best_only=True, save_weights_only=False, mode='min', period=1)

#     # Not used here. But leaving it here as a reminder for future
#     r_lr_plat = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=30, 
#                                   verbose=0, mode='auto', min_delta=0.0001, cooldown=0, min_lr=0)
    
#     csv_logger = CSVLogger(os.path.join(OUTPUT_PATH, 'training_log_' + time.ctime().replace(" ","_") + '.log'), append=True)
    
#     history = model.fit(x_t, y_t, epochs=params["epochs"], verbose=2, batch_size=BATCH_SIZE,
#                         shuffle=False, validation_data=(trim_dataset(x_val, BATCH_SIZE),
#                         trim_dataset(y_val, BATCH_SIZE)), callbacks=[es, mcp, csv_logger])
    
#     print("saving model...")
#     pickle.dump(model, open("lstm_model", "wb"))

# # model.evaluate(x_test_t, y_test_t, batch_size=BATCH_SIZE
# y_pred = model.predict(trim_dataset(x_test_t, BATCH_SIZE), batch_size=BATCH_SIZE)
# y_pred = y_pred.flatten()
# y_test_t = trim_dataset(y_test_t, BATCH_SIZE)
# error = mean_squared_error(y_test_t, y_pred)
# print("Error is", error, y_pred.shape, y_test_t.shape)
# print(y_pred[0:15])
# print(y_test_t[0:15])

# # convert the predicted value to range of real data
# y_pred_org = (y_pred * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3]
# # min_max_scaler.inverse_transform(y_pred)
# y_test_t_org = (y_test_t * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3]
# # min_max_scaler.inverse_transform(y_test_t)
# print(y_pred_org[0:15])
# print(y_test_t_org[0:15])

# # Visualize the training data
# from matplotlib import pyplot as plt
# plt.figure()
# plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
# plt.title('Model loss')
# plt.ylabel('Loss')
# plt.xlabel('Epoch')
# plt.legend(['Train', 'Test'], loc='upper left')
# #plt.show()
# plt.savefig(os.path.join(OUTPUT_PATH, 'train_vis_BS_'+str(BATCH_SIZE)+"_"+time.ctime()+'.png'))

# # load the saved best model from above
# saved_model = load_model(os.path.join(OUTPUT_PATH, 'best_model.h5')) # , "lstm_best_7-3-19_12AM",
# print(saved_model)

# y_pred = saved_model.predict(trim_dataset(x_test_t, BATCH_SIZE), batch_size=BATCH_SIZE)
# y_pred = y_pred.flatten()
# y_test_t = trim_dataset(y_test_t, BATCH_SIZE)
# error = mean_squared_error(y_test_t, y_pred)
# print("Error is", error, y_pred.shape, y_test_t.shape)
# print(y_pred[0:15])
# print(y_test_t[0:15])
# y_pred_org = (y_pred * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3] # min_max_scaler.inverse_transform(y_pred)
# y_test_t_org = (y_test_t * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3] # min_max_scaler.inverse_transform(y_test_t)
# print(y_pred_org[0:15])
# print(y_test_t_org[0:15])

# # Visualize the prediction
# from matplotlib import pyplot as plt
# plt.figure()
# plt.plot(y_pred_org)
# plt.plot(y_test_t_org)
# plt.title('Prediction vs Real Stock Price')
# plt.ylabel('Price')
# plt.xlabel('Days')
# plt.legend(['Prediction', 'Real'], loc='upper left')
# #plt.show()
# plt.savefig(os.path.join(OUTPUT_PATH, 'pred_vs_real_BS'+str(BATCH_SIZE)+"_"+time.ctime()+'.png'))
# print_time("program completed ", stime)
